# %% [markdown]
# ### Import Packages

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from keras.layers import Input, Dense, Embedding, MaxPooling1D, Conv1D, SpatialDropout1D
from keras.layers import add, Dropout, PReLU, BatchNormalization, GlobalMaxPooling1D, MaxPooling1D
from keras.preprocessing import text, sequence
from keras.callbacks import Callback
from keras import optimizers
from keras import initializers, regularizers, constraints, callbacks
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from sklearn.svm import SVC, LinearSVC
from sklearn.calibration import CalibratedClassifierCV
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Read in datafile and Extract input and labels

# %%
train = pd.read_csv("TIL_NLP_train_dataset.csv")
test = pd.read_csv("TIL_NLP_test_dataset.csv")
print(train.shape)
print(test.shape)

train_input = train["word_representation"]
train_labels = train[train.columns[2:]]
test_input = test["word_representation"]
test_id = test["id"]

print(train_input.head(1))
print(train_labels.head(1))
print(test_input.head(1))

x_train, x_test, y_train, y_test = train_test_split(train_input, train_labels, test_size=0.15, shuffle = True, random_state = 255)
# Out:
# (7380, 7)
# (2460, 2)
# 0    w7718 w173355 w138132 w232277 w90685 w314686 w...
# Name: word_representation, dtype: object
#    outwear  top  trousers  women dresses  women skirts
# 0        1    0         1              0             0
# 0    w373517 w383437 w374393 w87179 w289496 w327385...
# Name: word_representation, dtype: object

# %%
class RocAucEvaluation(Callback):
    def __init__(self, validation_data=(), interval=1):
        super(Callback, self).__init__()

        self.interval = interval
        self.X_val, self.y_val = validation_data

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict(self.X_val, verbose=0)
            score = roc_auc_score(self.y_val, y_pred)
            print("\n ROC-AUC - epoch: %d - score: %.6f \n" % (epoch+1, score))

def schedule(ind):
    a = [0.001, 0.0005, 0.0001, 0.0001]
    return a[ind]

# %% [markdown]
# ### Tokenise and pad

# %%
max_features = 100000
maxlen = 100
embed_size = 100

print('preprocessing start')

# finally, vectorize the text samples into a 2D integer tensor
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(x_train) + list(x_test) + list(test_input))

X_train1 = tokenizer.texts_to_sequences(x_train)
X_test1 = tokenizer.texts_to_sequences(x_test)
x_train_seq = sequence.pad_sequences(X_train1, maxlen=maxlen)
x_test_seq = sequence.pad_sequences(X_test1, maxlen=maxlen)


word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# preprocessing start
# Found 4620 unique tokens.

# %% [markdown]
# ### Create embedding dictionary and matrix

# %%
### Read pkl file provided
import gc
import pickle 
with open("word_embeddings.pkl",'rb') as g:
    embeddings_index = pickle.load(g)

all_embs = np.stack(embeddings_index.values())
emb_mean, emb_std = all_embs.mean(), all_embs.std()

word_index = tokenizer.word_index
nb_words = len(word_index)+1
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector
        
print('preprocessing done')
# Out:
# C:\Users\lim_k\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# preprocessing done

# %%
filter_nr = 64
filter_size = 6
max_pool_size = 4
max_pool_strides = 2
train_embed = False
conv_kern_reg = regularizers.l2(0.00001)
conv_bias_reg = regularizers.l2(0.00001)

# %%
model = Sequential()
model.add(Embedding(nb_words, embed_size, weights=[embedding_matrix], trainable=train_embed))
model.add(Conv1D(filters = 256, kernel_size=6, padding='same', activation='relu',
                kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(Dropout(0.5))
model.add(Conv1D(filters = 128, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(BatchNormalization())
model.add(Conv1D(filters = 64, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(Conv1D(filters = 32, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(Dropout(0.2))
model.add(Conv1D(filters = 16, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(BatchNormalization())
model.add(Conv1D(filters = 8, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(MaxPooling1D(pool_size=2))
model.add(Bidirectional(LSTM(150)))
model.add(Dense(5, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 100)         462100
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 256)         153856
# _________________________________________________________________
# dropout (Dropout)            (None, None, 256)         0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 128)         196736
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 128)         512
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, None, 64)          49216
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, None, 32)          12320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 32)          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, None, 16)          3088
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 16)          64
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, None, 8)           776
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, None, 8)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 300)               190800
# _________________________________________________________________
# dense (Dense)                (None, 5)                 1505
# =================================================================
# Total params: 1,070,973
# Trainable params: 608,585
# Non-trainable params: 462,388
# _________________________________________________________________
# None

# %%
batch_size = 128
epochs = 50

Xtrain, Xval, ytrain, yval = train_test_split(x_train_seq, y_train, train_size=0.90, random_state=233, shuffle = True)
history = model.fit(Xtrain, ytrain, batch_size=batch_size, epochs=epochs, 
                    validation_data=(Xval, yval),verbose=1, shuffle = True,
                   callbacks=[EarlyStopping(monitor='val_loss', patience=5, min_delta=0.00005)])
# Out:
# Train on 5645 samples, validate on 628 samples
# Epoch 1/50
#  512/5645 [=>............................] - ETA: 56s - loss: 0.6540 - accuracy: 0.6167 WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-d0441edb6d30> in <module>
#       5 history = model.fit(Xtrain, ytrain, batch_size=batch_size, epochs=epochs,
#       6                     validation_data=(Xval, yval),verbose=1, shuffle = True,
# ----> 7                    callbacks=[EarlyStopping(monitor='val_loss', patience=5, min_delta=0.00005)])
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred_NN = model.predict(x_test_seq, verbose=0)
preds_labels = [[1 if x > 0.5 else 0 for idx,x in enumerate(i) ] for i in y_pred_NN]

# %% [markdown]
# ### TFIDF for CatBoost and LinearSVC

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

cvect = TfidfVectorizer(analyzer='word', ngram_range=(1,6),max_df=1.0,
                        max_features=None, min_df=1)

cvect.fit(x_train)
x_train_vectorized = cvect.transform(x_train)
x_test_vectorized = cvect.transform(x_test)

print(x_train_vectorized.shape)
print(x_test_vectorized.shape)
print(y_train.shape)
# Out:
# (6273, 288021)
# (1107, 288021)
# (6273, 5)

# %% [markdown]
# ### LinearSVC

# %%
clf1 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 
clf2 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 
clf3 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 
clf4 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 
clf5 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 

"outwear", "top", "trousers", "women dresses", "women skirts"
clf1.fit(x_train_vectorized, y_train["outwear"])
clf2.fit(x_train_vectorized, y_train["top"])
clf3.fit(x_train_vectorized, y_train["trousers"])
clf4.fit(x_train_vectorized, y_train["women dresses"])
clf5.fit(x_train_vectorized, y_train["women skirts"])


y_pred1 = clf1.predict_proba(x_test_vectorized)[:, 1]
y_pred2 = clf2.predict_proba(x_test_vectorized)[:, 1]
y_pred3 = clf3.predict_proba(x_test_vectorized)[:, 1]
y_pred4 = clf4.predict_proba(x_test_vectorized)[:, 1]
y_pred5 = clf5.predict_proba(x_test_vectorized)[:, 1]

y_pred_class_svc = np.stack((y_pred1,y_pred2,y_pred3, y_pred4, y_pred5), axis = 1)

# %%
from sklearn.metrics import accuracy_score 
y_pred1 = clf1.predict(x_test_vectorized)
y_pred2 = clf2.predict(x_test_vectorized)
y_pred3 = clf3.predict(x_test_vectorized)
y_pred4 = clf4.predict(x_test_vectorized)
y_pred5 = clf5.predict(x_test_vectorized)

y_pred = np.stack((y_pred1,y_pred2,y_pred3, y_pred4, y_pred5), axis = 1)
print("Accuracy score using CountVectorizer and LinearSVC: {}".format(accuracy_score(y_pred, y_test)))
# Out:
# Accuracy score using CountVectorizer and LinearSVC: 0.7533875338753387

# %% [markdown]
# ### CatBoost

# %%
from catboost import CatBoostClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import MultiLabelBinarizer

ovr = OneVsRestClassifier(estimator=CatBoostClassifier(loss_function='MultiClass',eval_metric='AUC'
                                                       , verbose=1,learning_rate = 0.1,
                                                      iterations = 500, rsm = 0.1))
ovr.fit(x_train_vectorized,y_train)

y_pred = ovr.predict(x_test_vectorized)


from sklearn.metrics import accuracy_score 
print("Accuracy score using CountVectorizer and CatBoost: {}".format(accuracy_score(y_pred, y_test)))
# Out:
# 0:	total: 1.61s	remaining: 13m 25s
# 1:	total: 3.02s	remaining: 12m 33s
# 2:	total: 4.58s	remaining: 12m 39s
# 3:	total: 6.6s	remaining: 13m 38s
# 4:	total: 8.38s	remaining: 13m 49s
# 5:	total: 10.3s	remaining: 14m 4s
# 6:	total: 12.1s	remaining: 14m 11s
# 7:	total: 13.9s	remaining: 14m 12s
# 8:	total: 15.7s	remaining: 14m 17s
# 9:	total: 17.3s	remaining: 14m 6s
# 10:	total: 18.7s	remaining: 13m 50s
# 11:	total: 20.1s	remaining: 13m 37s
# 12:	total: 21.6s	remaining: 13m 28s
# 13:	total: 22.9s	remaining: 13m 16s
# 14:	total: 24.3s	remaining: 13m 6s
# 15:	total: 25.7s	remaining: 12m 57s
# 16:	total: 27.1s	remaining: 12m 48s
# 17:	total: 28.6s	remaining: 12m 45s
# 18:	total: 30s	remaining: 12m 38s
# 19:	total: 31.3s	remaining: 12m 30s
# 20:	total: 32.6s	remaining: 12m 24s
# 21:	total: 34s	remaining: 12m 19s
# 22:	total: 36s	remaining: 12m 27s
# 23:	total: 37.9s	remaining: 12m 30s
# 24:	total: 39.7s	remaining: 12m 34s
# 25:	total: 41.8s	remaining: 12m 42s
# 26:	total: 43.7s	remaining: 12m 44s
# 27:	total: 45.1s	remaining: 12m 40s
# 28:	total: 46.6s	remaining: 12m 36s
# 29:	total: 48s	remaining: 12m 32s
# 30:	total: 49.4s	remaining: 12m 27s
# 31:	total: 51.1s	remaining: 12m 26s
# 32:	total: 52.6s	remaining: 12m 24s
# 33:	total: 54s	remaining: 12m 20s
# 34:	total: 55.5s	remaining: 12m 17s
# 35:	total: 56.9s	remaining: 12m 13s
# 36:	total: 58.5s	remaining: 12m 11s
# 37:	total: 1m	remaining: 12m 10s
# 38:	total: 1m 1s	remaining: 12m 11s
# 39:	total: 1m 3s	remaining: 12m 8s
# 40:	total: 1m 4s	remaining: 12m 5s
# 41:	total: 1m 6s	remaining: 12m 3s
# 42:	total: 1m 8s	remaining: 12m 3s
# 43:	total: 1m 9s	remaining: 12m 3s
# 44:	total: 1m 11s	remaining: 12m 2s
# 45:	total: 1m 12s	remaining: 12m
# 46:	total: 1m 14s	remaining: 11m 57s
# 47:	total: 1m 15s	remaining: 11m 55s
# 48:	total: 1m 17s	remaining: 11m 52s
# 49:	total: 1m 18s	remaining: 11m 50s
# 50:	total: 1m 20s	remaining: 11m 48s
# 51:	total: 1m 21s	remaining: 11m 46s
# 52:	total: 1m 23s	remaining: 11m 43s
# 53:	total: 1m 24s	remaining: 11m 41s
# 54:	total: 1m 26s	remaining: 11m 38s
# 55:	total: 1m 27s	remaining: 11m 37s
# 56:	total: 1m 29s	remaining: 11m 34s
# 57:	total: 1m 30s	remaining: 11m 32s
# 58:	total: 1m 32s	remaining: 11m 30s
# 59:	total: 1m 33s	remaining: 11m 28s
# 60:	total: 1m 35s	remaining: 11m 26s
# 61:	total: 1m 37s	remaining: 11m 25s
# 62:	total: 1m 38s	remaining: 11m 26s
# 63:	total: 1m 40s	remaining: 11m 25s
# 64:	total: 1m 42s	remaining: 11m 23s
# 65:	total: 1m 43s	remaining: 11m 21s
# 66:	total: 1m 45s	remaining: 11m 20s
# 67:	total: 1m 46s	remaining: 11m 18s
# 68:	total: 1m 48s	remaining: 11m 16s
# 69:	total: 1m 50s	remaining: 11m 16s
# 70:	total: 1m 52s	remaining: 11m 17s
# 71:	total: 1m 53s	remaining: 11m 16s
# 72:	total: 1m 55s	remaining: 11m 17s
# 73:	total: 1m 57s	remaining: 11m 14s
# 74:	total: 1m 59s	remaining: 11m 15s
# 75:	total: 2m 1s	remaining: 11m 16s
# 76:	total: 2m 3s	remaining: 11m 17s
# 77:	total: 2m 5s	remaining: 11m 16s
# 78:	total: 2m 7s	remaining: 11m 17s
# 79:	total: 2m 9s	remaining: 11m 19s
# 80:	total: 2m 11s	remaining: 11m 18s
# 81:	total: 2m 13s	remaining: 11m 20s
# 82:	total: 2m 14s	remaining: 11m 18s
# 83:	total: 2m 16s	remaining: 11m 16s
# 84:	total: 2m 18s	remaining: 11m 14s
# 85:	total: 2m 19s	remaining: 11m 13s
# 86:	total: 2m 21s	remaining: 11m 11s
# 87:	total: 2m 23s	remaining: 11m 9s
# 88:	total: 2m 24s	remaining: 11m 7s
# 89:	total: 2m 26s	remaining: 11m 5s
# 90:	total: 2m 27s	remaining: 11m 3s
# 91:	total: 2m 29s	remaining: 11m 1s
# 92:	total: 2m 30s	remaining: 10m 59s
# 93:	total: 2m 32s	remaining: 10m 57s
# 94:	total: 2m 33s	remaining: 10m 55s
# 95:	total: 2m 35s	remaining: 10m 53s
# 96:	total: 2m 36s	remaining: 10m 51s
# 97:	total: 2m 38s	remaining: 10m 49s
# 98:	total: 2m 39s	remaining: 10m 47s
# 99:	total: 2m 41s	remaining: 10m 46s
# 100:	total: 2m 43s	remaining: 10m 44s
# 101:	total: 2m 44s	remaining: 10m 43s
# 102:	total: 2m 46s	remaining: 10m 41s
# 103:	total: 2m 47s	remaining: 10m 38s
# 104:	total: 2m 49s	remaining: 10m 36s
# 105:	total: 2m 50s	remaining: 10m 34s
# 106:	total: 2m 52s	remaining: 10m 33s
# 107:	total: 2m 53s	remaining: 10m 31s
# 108:	total: 2m 55s	remaining: 10m 29s
# 109:	total: 2m 56s	remaining: 10m 26s
# 110:	total: 2m 58s	remaining: 10m 24s
# 111:	total: 2m 59s	remaining: 10m 23s
# 112:	total: 3m 1s	remaining: 10m 21s
# 113:	total: 3m 3s	remaining: 10m 19s
# 114:	total: 3m 4s	remaining: 10m 17s
# 115:	total: 3m 5s	remaining: 10m 15s
# 116:	total: 3m 7s	remaining: 10m 13s
# 117:	total: 3m 8s	remaining: 10m 11s
# 118:	total: 3m 10s	remaining: 10m 9s
# 119:	total: 3m 12s	remaining: 10m 9s
# 120:	total: 3m 14s	remaining: 10m 8s
# 121:	total: 3m 15s	remaining: 10m 7s
# 122:	total: 3m 17s	remaining: 10m 6s
# 123:	total: 3m 19s	remaining: 10m 6s
# 124:	total: 3m 21s	remaining: 10m 4s
# 125:	total: 3m 22s	remaining: 10m 2s
# 126:	total: 3m 24s	remaining: 10m 1s
# 127:	total: 3m 26s	remaining: 10m
# 128:	total: 3m 28s	remaining: 9m 59s
# 129:	total: 3m 30s	remaining: 9m 58s
# 130:	total: 3m 32s	remaining: 9m 57s
# 131:	total: 3m 34s	remaining: 9m 57s
# 132:	total: 3m 36s	remaining: 9m 57s
# 133:	total: 3m 38s	remaining: 9m 57s
# 134:	total: 3m 40s	remaining: 9m 56s
# 135:	total: 3m 42s	remaining: 9m 55s
# 136:	total: 3m 44s	remaining: 9m 54s
# 137:	total: 3m 46s	remaining: 9m 53s
# 138:	total: 3m 47s	remaining: 9m 51s
# 139:	total: 3m 49s	remaining: 9m 50s
# 140:	total: 3m 51s	remaining: 9m 49s
# 141:	total: 3m 53s	remaining: 9m 48s
# 142:	total: 3m 55s	remaining: 9m 47s
# 143:	total: 3m 57s	remaining: 9m 45s
# 144:	total: 3m 58s	remaining: 9m 44s
# 145:	total: 4m	remaining: 9m 43s
# 146:	total: 4m 2s	remaining: 9m 42s
# 147:	total: 4m 4s	remaining: 9m 41s
# 148:	total: 4m 6s	remaining: 9m 40s
# 149:	total: 4m 8s	remaining: 9m 39s
# 150:	total: 4m 9s	remaining: 9m 37s
# 151:	total: 4m 11s	remaining: 9m 36s
# 152:	total: 4m 13s	remaining: 9m 34s
# 153:	total: 4m 14s	remaining: 9m 32s
# 154:	total: 4m 16s	remaining: 9m 31s
# 155:	total: 4m 18s	remaining: 9m 29s
# 156:	total: 4m 19s	remaining: 9m 27s
# 157:	total: 4m 21s	remaining: 9m 26s
# 158:	total: 4m 23s	remaining: 9m 24s
# 159:	total: 4m 24s	remaining: 9m 22s
# 160:	total: 4m 26s	remaining: 9m 20s
# 161:	total: 4m 28s	remaining: 9m 19s
# 162:	total: 4m 29s	remaining: 9m 17s
# 163:	total: 4m 31s	remaining: 9m 16s
# 164:	total: 4m 33s	remaining: 9m 14s
# 165:	total: 4m 34s	remaining: 9m 13s
# 166:	total: 4m 36s	remaining: 9m 11s
# 167:	total: 4m 38s	remaining: 9m 9s
# 168:	total: 4m 39s	remaining: 9m 8s
# 169:	total: 4m 41s	remaining: 9m 6s
# 170:	total: 4m 43s	remaining: 9m 5s
# 171:	total: 4m 45s	remaining: 9m 3s
# 172:	total: 4m 46s	remaining: 9m 2s
# 173:	total: 4m 48s	remaining: 9m
# 174:	total: 4m 50s	remaining: 8m 59s
# 175:	total: 4m 52s	remaining: 8m 57s
# 176:	total: 4m 53s	remaining: 8m 56s
# 177:	total: 4m 55s	remaining: 8m 54s
# 178:	total: 4m 57s	remaining: 8m 53s
# 179:	total: 4m 58s	remaining: 8m 51s
# 180:	total: 5m	remaining: 8m 49s
# 181:	total: 5m 2s	remaining: 8m 48s
# 182:	total: 5m 3s	remaining: 8m 46s
# 183:	total: 5m 5s	remaining: 8m 44s
# 184:	total: 5m 7s	remaining: 8m 43s
# 185:	total: 5m 9s	remaining: 8m 42s
# 186:	total: 5m 11s	remaining: 8m 41s
# 187:	total: 5m 13s	remaining: 8m 39s
# 188:	total: 5m 14s	remaining: 8m 37s
# 189:	total: 5m 16s	remaining: 8m 36s
# 190:	total: 5m 18s	remaining: 8m 35s
# 191:	total: 5m 20s	remaining: 8m 34s
# 192:	total: 5m 22s	remaining: 8m 33s
# 193:	total: 5m 24s	remaining: 8m 31s
# 194:	total: 5m 26s	remaining: 8m 30s
# 195:	total: 5m 28s	remaining: 8m 28s
# 196:	total: 5m 29s	remaining: 8m 26s
# 197:	total: 5m 31s	remaining: 8m 25s
# 198:	total: 5m 32s	remaining: 8m 23s
# 199:	total: 5m 34s	remaining: 8m 21s
# 200:	total: 5m 35s	remaining: 8m 19s
# 201:	total: 5m 37s	remaining: 8m 18s
# 202:	total: 5m 39s	remaining: 8m 16s
# 203:	total: 5m 41s	remaining: 8m 15s
# 204:	total: 5m 43s	remaining: 8m 13s
# 205:	total: 5m 44s	remaining: 8m 11s
# 206:	total: 5m 46s	remaining: 8m 10s
# 207:	total: 5m 47s	remaining: 8m 8s
# 208:	total: 5m 49s	remaining: 8m 6s
# 209:	total: 5m 50s	remaining: 8m 4s
# 210:	total: 5m 52s	remaining: 8m 2s
# 211:	total: 5m 53s	remaining: 8m
# 212:	total: 5m 54s	remaining: 7m 58s
# 213:	total: 5m 56s	remaining: 7m 56s
# 214:	total: 5m 57s	remaining: 7m 54s
# 215:	total: 5m 59s	remaining: 7m 52s
# 216:	total: 6m	remaining: 7m 50s
# 217:	total: 6m 2s	remaining: 7m 48s
# 218:	total: 6m 3s	remaining: 7m 46s
# 219:	total: 6m 5s	remaining: 7m 44s
# 220:	total: 6m 6s	remaining: 7m 42s
# 221:	total: 6m 8s	remaining: 7m 40s
# 222:	total: 6m 9s	remaining: 7m 38s
# 223:	total: 6m 10s	remaining: 7m 37s
# 224:	total: 6m 12s	remaining: 7m 34s
# 225:	total: 6m 13s	remaining: 7m 33s
# 226:	total: 6m 15s	remaining: 7m 31s
# 227:	total: 6m 16s	remaining: 7m 29s
# 228:	total: 6m 17s	remaining: 7m 27s
# 229:	total: 6m 19s	remaining: 7m 25s
# 230:	total: 6m 20s	remaining: 7m 23s
# 231:	total: 6m 21s	remaining: 7m 21s
# 232:	total: 6m 23s	remaining: 7m 19s
# 233:	total: 6m 24s	remaining: 7m 17s
# 234:	total: 6m 25s	remaining: 7m 14s
# 235:	total: 6m 27s	remaining: 7m 12s
# 236:	total: 6m 28s	remaining: 7m 11s
# 237:	total: 6m 29s	remaining: 7m 9s
# 238:	total: 6m 31s	remaining: 7m 7s
# 239:	total: 6m 32s	remaining: 7m 5s
# 240:	total: 6m 33s	remaining: 7m 3s
# 241:	total: 6m 35s	remaining: 7m 1s
# 242:	total: 6m 36s	remaining: 6m 59s
# 243:	total: 6m 38s	remaining: 6m 57s
# 244:	total: 6m 39s	remaining: 6m 55s
# 245:	total: 6m 41s	remaining: 6m 54s
# 246:	total: 6m 42s	remaining: 6m 52s
# 247:	total: 6m 44s	remaining: 6m 50s
# 248:	total: 6m 45s	remaining: 6m 49s
# 249:	total: 6m 47s	remaining: 6m 47s
# 250:	total: 6m 49s	remaining: 6m 45s
# 251:	total: 6m 50s	remaining: 6m 44s
# 252:	total: 6m 52s	remaining: 6m 42s
# 253:	total: 6m 53s	remaining: 6m 40s
# 254:	total: 6m 55s	remaining: 6m 38s
# 255:	total: 6m 56s	remaining: 6m 37s
# 256:	total: 6m 58s	remaining: 6m 35s
# 257:	total: 6m 59s	remaining: 6m 33s
# 258:	total: 7m	remaining: 6m 31s
# 259:	total: 7m 2s	remaining: 6m 29s
# 260:	total: 7m 3s	remaining: 6m 27s
# 261:	total: 7m 5s	remaining: 6m 26s
# 262:	total: 7m 6s	remaining: 6m 24s
# 263:	total: 7m 7s	remaining: 6m 22s
# 264:	total: 7m 9s	remaining: 6m 20s
# 265:	total: 7m 10s	remaining: 6m 18s
# 266:	total: 7m 12s	remaining: 6m 17s
# 267:	total: 7m 13s	remaining: 6m 15s
# 268:	total: 7m 15s	remaining: 6m 13s
# 269:	total: 7m 16s	remaining: 6m 11s
# 270:	total: 7m 17s	remaining: 6m 9s
# 271:	total: 7m 19s	remaining: 6m 8s
# 272:	total: 7m 20s	remaining: 6m 6s
# 273:	total: 7m 22s	remaining: 6m 4s
# 274:	total: 7m 23s	remaining: 6m 2s
# 275:	total: 7m 24s	remaining: 6m 1s
# 276:	total: 7m 26s	remaining: 5m 59s
# 277:	total: 7m 27s	remaining: 5m 57s
# 278:	total: 7m 29s	remaining: 5m 56s
# 279:	total: 7m 30s	remaining: 5m 54s
# 280:	total: 7m 32s	remaining: 5m 52s
# 281:	total: 7m 33s	remaining: 5m 50s
# 282:	total: 7m 35s	remaining: 5m 48s
# 283:	total: 7m 36s	remaining: 5m 47s
# 284:	total: 7m 37s	remaining: 5m 45s
# 285:	total: 7m 39s	remaining: 5m 43s
# 286:	total: 7m 40s	remaining: 5m 41s
# 287:	total: 7m 42s	remaining: 5m 40s
# 288:	total: 7m 43s	remaining: 5m 38s
# 289:	total: 7m 44s	remaining: 5m 36s
# 290:	total: 7m 46s	remaining: 5m 35s
# 291:	total: 7m 47s	remaining: 5m 33s
# 292:	total: 7m 49s	remaining: 5m 31s
# 293:	total: 7m 50s	remaining: 5m 29s
# 294:	total: 7m 52s	remaining: 5m 28s
# 295:	total: 7m 53s	remaining: 5m 26s
# 296:	total: 7m 54s	remaining: 5m 24s
# 297:	total: 7m 56s	remaining: 5m 23s
# 298:	total: 7m 58s	remaining: 5m 21s
# 299:	total: 7m 59s	remaining: 5m 19s
# 300:	total: 8m	remaining: 5m 17s
# 301:	total: 8m 2s	remaining: 5m 16s
# 302:	total: 8m 3s	remaining: 5m 14s
# 303:	total: 8m 5s	remaining: 5m 12s
# 304:	total: 8m 6s	remaining: 5m 11s
# 305:	total: 8m 8s	remaining: 5m 9s
# 306:	total: 8m 9s	remaining: 5m 7s
# 307:	total: 8m 10s	remaining: 5m 6s
# 308:	total: 8m 12s	remaining: 5m 4s
# 309:	total: 8m 13s	remaining: 5m 2s
# 310:	total: 8m 15s	remaining: 5m
# 311:	total: 8m 16s	remaining: 4m 59s
# 312:	total: 8m 17s	remaining: 4m 57s
# 313:	total: 8m 19s	remaining: 4m 55s
# 314:	total: 8m 20s	remaining: 4m 54s
# 315:	total: 8m 22s	remaining: 4m 52s
# 316:	total: 8m 23s	remaining: 4m 50s
# 317:	total: 8m 24s	remaining: 4m 48s
# 318:	total: 8m 26s	remaining: 4m 47s
# 319:	total: 8m 27s	remaining: 4m 45s
# 320:	total: 8m 28s	remaining: 4m 43s
# 321:	total: 8m 30s	remaining: 4m 42s
# 322:	total: 8m 32s	remaining: 4m 40s
# 323:	total: 8m 33s	remaining: 4m 38s
# 324:	total: 8m 34s	remaining: 4m 37s
# 325:	total: 8m 36s	remaining: 4m 35s
# 326:	total: 8m 37s	remaining: 4m 33s
# 327:	total: 8m 39s	remaining: 4m 32s
# 328:	total: 8m 40s	remaining: 4m 30s
# 329:	total: 8m 41s	remaining: 4m 28s
# 330:	total: 8m 43s	remaining: 4m 27s
# 331:	total: 8m 44s	remaining: 4m 25s
# 332:	total: 8m 45s	remaining: 4m 23s
# 333:	total: 8m 47s	remaining: 4m 22s
# 334:	total: 8m 48s	remaining: 4m 20s
# 335:	total: 8m 50s	remaining: 4m 18s
# 336:	total: 8m 51s	remaining: 4m 17s
# 337:	total: 8m 52s	remaining: 4m 15s
# 338:	total: 8m 54s	remaining: 4m 13s
# 339:	total: 8m 55s	remaining: 4m 12s
# 340:	total: 8m 56s	remaining: 4m 10s
# 341:	total: 8m 58s	remaining: 4m 8s
# 342:	total: 8m 59s	remaining: 4m 7s
# 343:	total: 9m 1s	remaining: 4m 5s
# 344:	total: 9m 2s	remaining: 4m 3s
# 345:	total: 9m 3s	remaining: 4m 2s
# 346:	total: 9m 5s	remaining: 4m
# 347:	total: 9m 6s	remaining: 3m 58s
# 348:	total: 9m 7s	remaining: 3m 56s
# 349:	total: 9m 9s	remaining: 3m 55s
# 350:	total: 9m 10s	remaining: 3m 53s
# 351:	total: 9m 11s	remaining: 3m 52s
# 352:	total: 9m 13s	remaining: 3m 50s
# 353:	total: 9m 14s	remaining: 3m 48s
# 354:	total: 9m 15s	remaining: 3m 47s
# 355:	total: 9m 17s	remaining: 3m 45s
# 356:	total: 9m 18s	remaining: 3m 43s
# 357:	total: 9m 20s	remaining: 3m 42s
# 358:	total: 9m 21s	remaining: 3m 40s
# 359:	total: 9m 22s	remaining: 3m 38s
# 360:	total: 9m 24s	remaining: 3m 37s
# 361:	total: 9m 25s	remaining: 3m 35s
# 362:	total: 9m 26s	remaining: 3m 33s
# 363:	total: 9m 28s	remaining: 3m 32s
# 364:	total: 9m 29s	remaining: 3m 30s
# 365:	total: 9m 31s	remaining: 3m 29s
# 366:	total: 9m 32s	remaining: 3m 27s
# 367:	total: 9m 33s	remaining: 3m 25s
# 368:	total: 9m 35s	remaining: 3m 24s
# 369:	total: 9m 36s	remaining: 3m 22s
# 370:	total: 9m 37s	remaining: 3m 20s
# 371:	total: 9m 39s	remaining: 3m 19s
# 372:	total: 9m 40s	remaining: 3m 17s
# 373:	total: 9m 42s	remaining: 3m 16s
# 374:	total: 9m 43s	remaining: 3m 14s
# 375:	total: 9m 45s	remaining: 3m 12s
# 376:	total: 9m 46s	remaining: 3m 11s
# 377:	total: 9m 47s	remaining: 3m 9s
# 378:	total: 9m 49s	remaining: 3m 8s
# 379:	total: 9m 50s	remaining: 3m 6s
# 380:	total: 9m 52s	remaining: 3m 5s
# 381:	total: 9m 53s	remaining: 3m 3s
# 382:	total: 9m 55s	remaining: 3m 1s
# 383:	total: 9m 56s	remaining: 3m
# 384:	total: 9m 58s	remaining: 2m 58s
# 385:	total: 9m 59s	remaining: 2m 57s
# 386:	total: 10m 1s	remaining: 2m 55s
# 387:	total: 10m 2s	remaining: 2m 53s
# 388:	total: 10m 4s	remaining: 2m 52s
# 389:	total: 10m 5s	remaining: 2m 50s
# 390:	total: 10m 6s	remaining: 2m 49s
# 391:	total: 10m 8s	remaining: 2m 47s
# 392:	total: 10m 9s	remaining: 2m 46s
# 393:	total: 10m 11s	remaining: 2m 44s
# 394:	total: 10m 12s	remaining: 2m 42s
# 395:	total: 10m 14s	remaining: 2m 41s
# 396:	total: 10m 15s	remaining: 2m 39s
# 397:	total: 10m 17s	remaining: 2m 38s
# 398:	total: 10m 18s	remaining: 2m 36s
# 399:	total: 10m 20s	remaining: 2m 35s
# 400:	total: 10m 21s	remaining: 2m 33s
# 401:	total: 10m 23s	remaining: 2m 31s
# 402:	total: 10m 24s	remaining: 2m 30s
# 403:	total: 10m 26s	remaining: 2m 28s
# 404:	total: 10m 27s	remaining: 2m 27s
# 405:	total: 10m 28s	remaining: 2m 25s
# 406:	total: 10m 30s	remaining: 2m 24s
# 407:	total: 10m 31s	remaining: 2m 22s
# 408:	total: 10m 33s	remaining: 2m 20s
# 409:	total: 10m 34s	remaining: 2m 19s
# 410:	total: 10m 36s	remaining: 2m 17s
# 411:	total: 10m 37s	remaining: 2m 16s
# 412:	total: 10m 38s	remaining: 2m 14s
# 413:	total: 10m 40s	remaining: 2m 13s
# 414:	total: 10m 41s	remaining: 2m 11s
# 415:	total: 10m 43s	remaining: 2m 9s
# 416:	total: 10m 44s	remaining: 2m 8s
# 417:	total: 10m 45s	remaining: 2m 6s
# 418:	total: 10m 47s	remaining: 2m 5s
# 419:	total: 10m 48s	remaining: 2m 3s
# 420:	total: 10m 50s	remaining: 2m 1s
# 421:	total: 10m 51s	remaining: 2m
# 422:	total: 10m 52s	remaining: 1m 58s
# 423:	total: 10m 54s	remaining: 1m 57s
# 424:	total: 10m 55s	remaining: 1m 55s
# 425:	total: 10m 56s	remaining: 1m 54s
# 426:	total: 10m 58s	remaining: 1m 52s
# 427:	total: 10m 59s	remaining: 1m 50s
# 428:	total: 11m 1s	remaining: 1m 49s
# 429:	total: 11m 2s	remaining: 1m 47s
# 430:	total: 11m 3s	remaining: 1m 46s
# 431:	total: 11m 5s	remaining: 1m 44s
# 432:	total: 11m 7s	remaining: 1m 43s
# 433:	total: 11m 8s	remaining: 1m 41s
# 434:	total: 11m 10s	remaining: 1m 40s
# 435:	total: 11m 11s	remaining: 1m 38s
# 436:	total: 11m 12s	remaining: 1m 37s
# 437:	total: 11m 14s	remaining: 1m 35s
# 438:	total: 11m 15s	remaining: 1m 33s
# 439:	total: 11m 17s	remaining: 1m 32s
# 440:	total: 11m 18s	remaining: 1m 30s
# 441:	total: 11m 20s	remaining: 1m 29s
# 442:	total: 11m 21s	remaining: 1m 27s
# 443:	total: 11m 23s	remaining: 1m 26s
# 444:	total: 11m 24s	remaining: 1m 24s
# 445:	total: 11m 26s	remaining: 1m 23s
# 446:	total: 11m 27s	remaining: 1m 21s
# 447:	total: 11m 29s	remaining: 1m 20s
# 448:	total: 11m 31s	remaining: 1m 18s
# 449:	total: 11m 32s	remaining: 1m 16s
# 450:	total: 11m 33s	remaining: 1m 15s
# 451:	total: 11m 35s	remaining: 1m 13s
# 452:	total: 11m 36s	remaining: 1m 12s
# 453:	total: 11m 38s	remaining: 1m 10s
# 454:	total: 11m 39s	remaining: 1m 9s
# 455:	total: 11m 41s	remaining: 1m 7s
# 456:	total: 11m 43s	remaining: 1m 6s
# 457:	total: 11m 44s	remaining: 1m 4s
# 458:	total: 11m 45s	remaining: 1m 3s
# 459:	total: 11m 47s	remaining: 1m 1s
# 460:	total: 11m 48s	remaining: 60s
# 461:	total: 11m 50s	remaining: 58.4s
# 462:	total: 11m 51s	remaining: 56.9s
# 463:	total: 11m 53s	remaining: 55.3s
# 464:	total: 11m 54s	remaining: 53.8s
# 465:	total: 11m 55s	remaining: 52.2s
# 466:	total: 11m 57s	remaining: 50.7s
# 467:	total: 11m 58s	remaining: 49.2s
# 468:	total: 12m	remaining: 47.6s
# 469:	total: 12m 1s	remaining: 46.1s
# 470:	total: 12m 2s	remaining: 44.5s
# 471:	total: 12m 4s	remaining: 43s
# 472:	total: 12m 5s	remaining: 41.4s
# 473:	total: 12m 7s	remaining: 39.9s
# 474:	total: 12m 8s	remaining: 38.4s
# 475:	total: 12m 10s	remaining: 36.8s
# 476:	total: 12m 12s	remaining: 35.3s
# 477:	total: 12m 14s	remaining: 33.8s
# 478:	total: 12m 15s	remaining: 32.3s
# 479:	total: 12m 17s	remaining: 30.7s
# 480:	total: 12m 18s	remaining: 29.2s
# 481:	total: 12m 20s	remaining: 27.6s
# 482:	total: 12m 21s	remaining: 26.1s
# 483:	total: 12m 22s	remaining: 24.6s
# 484:	total: 12m 24s	remaining: 23s
# 485:	total: 12m 25s	remaining: 21.5s
# 486:	total: 12m 26s	remaining: 19.9s
# 487:	total: 12m 28s	remaining: 18.4s
# 488:	total: 12m 29s	remaining: 16.9s
# 489:	total: 12m 31s	remaining: 15.3s
# 490:	total: 12m 32s	remaining: 13.8s
# 491:	total: 12m 33s	remaining: 12.3s
# 492:	total: 12m 35s	remaining: 10.7s
# 493:	total: 12m 36s	remaining: 9.19s
# 494:	total: 12m 37s	remaining: 7.65s
# 495:	total: 12m 39s	remaining: 6.12s
# 496:	total: 12m 40s	remaining: 4.59s
# 497:	total: 12m 41s	remaining: 3.06s
# 498:	total: 12m 43s	remaining: 1.53s
# 499:	total: 12m 44s	remaining: 0us
# 0:	total: 1.47s	remaining: 12m 12s
# 1:	total: 2.81s	remaining: 11m 40s
# 2:	total: 4.18s	remaining: 11m 32s
# 3:	total: 5.59s	remaining: 11m 33s
# 4:	total: 6.98s	remaining: 11m 31s
# 5:	total: 8.35s	remaining: 11m 27s
# 6:	total: 9.72s	remaining: 11m 24s
# 7:	total: 11.1s	remaining: 11m 23s
# 8:	total: 12.5s	remaining: 11m 20s
# 9:	total: 13.9s	remaining: 11m 19s
# 10:	total: 15.3s	remaining: 11m 18s
# 11:	total: 16.7s	remaining: 11m 17s
# 12:	total: 18.1s	remaining: 11m 18s
# 13:	total: 19.5s	remaining: 11m 17s
# 14:	total: 20.9s	remaining: 11m 16s
# 15:	total: 22.3s	remaining: 11m 15s
# 16:	total: 23.7s	remaining: 11m 13s
# 17:	total: 25.1s	remaining: 11m 11s
# 18:	total: 26.5s	remaining: 11m 10s
# 19:	total: 27.9s	remaining: 11m 8s
# 20:	total: 29.3s	remaining: 11m 7s
# 21:	total: 30.8s	remaining: 11m 8s
# 22:	total: 32.1s	remaining: 11m 6s
# 23:	total: 33.5s	remaining: 11m 4s
# 24:	total: 35s	remaining: 11m 4s
# 25:	total: 36.3s	remaining: 11m 2s
# 26:	total: 37.7s	remaining: 11m
# 27:	total: 39s	remaining: 10m 57s
# 28:	total: 40.4s	remaining: 10m 55s
# 29:	total: 41.9s	remaining: 10m 55s
# 30:	total: 43.4s	remaining: 10m 55s
# 31:	total: 44.8s	remaining: 10m 54s
# 32:	total: 46.1s	remaining: 10m 53s
# 33:	total: 47.6s	remaining: 10m 52s
# 34:	total: 49.4s	remaining: 10m 56s
# 35:	total: 51.3s	remaining: 11m 1s
# 36:	total: 53s	remaining: 11m 3s
# 37:	total: 55.1s	remaining: 11m 9s
# 38:	total: 57.1s	remaining: 11m 14s
# 39:	total: 59s	remaining: 11m 18s
# 40:	total: 1m	remaining: 11m 21s
# 41:	total: 1m 2s	remaining: 11m 25s
# 42:	total: 1m 4s	remaining: 11m 27s
# 43:	total: 1m 6s	remaining: 11m 26s
# 44:	total: 1m 7s	remaining: 11m 23s
# 45:	total: 1m 9s	remaining: 11m 21s
# 46:	total: 1m 10s	remaining: 11m 18s
# 47:	total: 1m 11s	remaining: 11m 16s
# 48:	total: 1m 13s	remaining: 11m 13s
# 49:	total: 1m 14s	remaining: 11m 10s
# 50:	total: 1m 15s	remaining: 11m 7s
# 51:	total: 1m 17s	remaining: 11m 3s
# 52:	total: 1m 18s	remaining: 11m
# 53:	total: 1m 19s	remaining: 10m 57s
# 54:	total: 1m 20s	remaining: 10m 54s
# 55:	total: 1m 22s	remaining: 10m 50s
# 56:	total: 1m 23s	remaining: 10m 47s
# 57:	total: 1m 24s	remaining: 10m 44s
# 58:	total: 1m 25s	remaining: 10m 41s
# 59:	total: 1m 27s	remaining: 10m 38s
# 60:	total: 1m 28s	remaining: 10m 36s
# 61:	total: 1m 29s	remaining: 10m 34s
# 62:	total: 1m 31s	remaining: 10m 32s
# 63:	total: 1m 32s	remaining: 10m 29s
# 64:	total: 1m 33s	remaining: 10m 27s
# 65:	total: 1m 35s	remaining: 10m 26s
# 66:	total: 1m 36s	remaining: 10m 23s
# 67:	total: 1m 37s	remaining: 10m 22s
# 68:	total: 1m 39s	remaining: 10m 20s
# 69:	total: 1m 40s	remaining: 10m 19s
# 70:	total: 1m 42s	remaining: 10m 18s
# 71:	total: 1m 43s	remaining: 10m 16s
# 72:	total: 1m 45s	remaining: 10m 15s
# 73:	total: 1m 46s	remaining: 10m 14s
# 74:	total: 1m 48s	remaining: 10m 13s
# 75:	total: 1m 50s	remaining: 10m 14s
# 76:	total: 1m 51s	remaining: 10m 13s
# 77:	total: 1m 53s	remaining: 10m 11s
# 78:	total: 1m 54s	remaining: 10m 9s
# 79:	total: 1m 55s	remaining: 10m 7s
# 80:	total: 1m 57s	remaining: 10m 6s
# 81:	total: 1m 58s	remaining: 10m 5s
# 82:	total: 2m	remaining: 10m 3s
# 83:	total: 2m 1s	remaining: 10m 1s
# 84:	total: 2m 2s	remaining: 10m
# 85:	total: 2m 4s	remaining: 9m 59s
# 86:	total: 2m 5s	remaining: 9m 57s
# 87:	total: 2m 7s	remaining: 9m 56s
# 88:	total: 2m 8s	remaining: 9m 55s
# 89:	total: 2m 10s	remaining: 9m 53s
# 90:	total: 2m 11s	remaining: 9m 51s
# 91:	total: 2m 12s	remaining: 9m 48s
# 92:	total: 2m 14s	remaining: 9m 46s
# 93:	total: 2m 15s	remaining: 9m 44s
# 94:	total: 2m 16s	remaining: 9m 42s
# 95:	total: 2m 17s	remaining: 9m 40s
# 96:	total: 2m 19s	remaining: 9m 38s
# 97:	total: 2m 20s	remaining: 9m 36s
# 98:	total: 2m 21s	remaining: 9m 34s
# 99:	total: 2m 23s	remaining: 9m 32s
# 100:	total: 2m 24s	remaining: 9m 30s
# 101:	total: 2m 25s	remaining: 9m 28s
# 102:	total: 2m 27s	remaining: 9m 26s
# 103:	total: 2m 28s	remaining: 9m 25s
# 104:	total: 2m 29s	remaining: 9m 23s
# 105:	total: 2m 30s	remaining: 9m 21s
# 106:	total: 2m 32s	remaining: 9m 19s
# 107:	total: 2m 33s	remaining: 9m 17s
# 108:	total: 2m 35s	remaining: 9m 16s
# 109:	total: 2m 36s	remaining: 9m 14s
# 110:	total: 2m 37s	remaining: 9m 13s
# 111:	total: 2m 39s	remaining: 9m 12s
# 112:	total: 2m 40s	remaining: 9m 10s
# 113:	total: 2m 42s	remaining: 9m 9s
# 114:	total: 2m 43s	remaining: 9m 7s
# 115:	total: 2m 45s	remaining: 9m 6s
# 116:	total: 2m 46s	remaining: 9m 4s
# 117:	total: 2m 47s	remaining: 9m 3s
# 118:	total: 2m 49s	remaining: 9m 1s
# 119:	total: 2m 50s	remaining: 8m 59s
# 120:	total: 2m 51s	remaining: 8m 57s
# 121:	total: 2m 52s	remaining: 8m 55s
# 122:	total: 2m 54s	remaining: 8m 53s
# 123:	total: 2m 55s	remaining: 8m 51s
# 124:	total: 2m 56s	remaining: 8m 49s
# 125:	total: 2m 57s	remaining: 8m 48s
# 126:	total: 2m 59s	remaining: 8m 46s
# 127:	total: 3m	remaining: 8m 44s
# 128:	total: 3m 1s	remaining: 8m 42s
# 129:	total: 3m 2s	remaining: 8m 40s
# 130:	total: 3m 4s	remaining: 8m 39s
# 131:	total: 3m 5s	remaining: 8m 38s
# 132:	total: 3m 7s	remaining: 8m 36s
# 133:	total: 3m 8s	remaining: 8m 35s
# 134:	total: 3m 10s	remaining: 8m 33s
# 135:	total: 3m 11s	remaining: 8m 32s
# 136:	total: 3m 12s	remaining: 8m 30s
# 137:	total: 3m 14s	remaining: 8m 29s
# 138:	total: 3m 15s	remaining: 8m 27s
# 139:	total: 3m 16s	remaining: 8m 26s
# 140:	total: 3m 18s	remaining: 8m 25s
# 141:	total: 3m 19s	remaining: 8m 23s
# 142:	total: 3m 21s	remaining: 8m 22s
# 143:	total: 3m 22s	remaining: 8m 21s
# 144:	total: 3m 24s	remaining: 8m 19s
# 145:	total: 3m 25s	remaining: 8m 17s
# 146:	total: 3m 26s	remaining: 8m 16s
# 147:	total: 3m 27s	remaining: 8m 14s
# 148:	total: 3m 29s	remaining: 8m 12s
# 149:	total: 3m 30s	remaining: 8m 11s
# 150:	total: 3m 31s	remaining: 8m 9s
# 151:	total: 3m 33s	remaining: 8m 7s
# 152:	total: 3m 34s	remaining: 8m 6s
# 153:	total: 3m 35s	remaining: 8m 4s
# 154:	total: 3m 36s	remaining: 8m 2s
# 155:	total: 3m 38s	remaining: 8m 1s
# 156:	total: 3m 39s	remaining: 7m 59s
# 157:	total: 3m 40s	remaining: 7m 58s
# 158:	total: 3m 42s	remaining: 7m 56s
# 159:	total: 3m 43s	remaining: 7m 54s
# 160:	total: 3m 44s	remaining: 7m 53s
# 161:	total: 3m 46s	remaining: 7m 52s
# 162:	total: 3m 47s	remaining: 7m 50s
# 163:	total: 3m 49s	remaining: 7m 49s
# 164:	total: 3m 50s	remaining: 7m 47s
# 165:	total: 3m 51s	remaining: 7m 46s
# 166:	total: 3m 53s	remaining: 7m 44s
# 167:	total: 3m 54s	remaining: 7m 43s
# 168:	total: 3m 55s	remaining: 7m 41s
# 169:	total: 3m 56s	remaining: 7m 39s
# 170:	total: 3m 58s	remaining: 7m 38s
# 171:	total: 3m 59s	remaining: 7m 36s
# 172:	total: 4m	remaining: 7m 35s
# 173:	total: 4m 2s	remaining: 7m 34s
# 174:	total: 4m 3s	remaining: 7m 32s
# 175:	total: 4m 5s	remaining: 7m 31s
# 176:	total: 4m 6s	remaining: 7m 29s
# 177:	total: 4m 7s	remaining: 7m 28s
# 178:	total: 4m 8s	remaining: 7m 26s
# 179:	total: 4m 10s	remaining: 7m 24s
# 180:	total: 4m 11s	remaining: 7m 23s
# 181:	total: 4m 12s	remaining: 7m 21s
# 182:	total: 4m 14s	remaining: 7m 20s
# 183:	total: 4m 15s	remaining: 7m 18s
# 184:	total: 4m 16s	remaining: 7m 16s
# 185:	total: 4m 17s	remaining: 7m 15s
# 186:	total: 4m 19s	remaining: 7m 13s
# 187:	total: 4m 20s	remaining: 7m 12s
# 188:	total: 4m 21s	remaining: 7m 10s
# 189:	total: 4m 23s	remaining: 7m 9s
# 190:	total: 4m 24s	remaining: 7m 7s
# 191:	total: 4m 25s	remaining: 7m 5s
# 192:	total: 4m 26s	remaining: 7m 4s
# 193:	total: 4m 28s	remaining: 7m 2s
# 194:	total: 4m 29s	remaining: 7m 1s
# 195:	total: 4m 30s	remaining: 7m
# 196:	total: 4m 32s	remaining: 6m 58s
# 197:	total: 4m 33s	remaining: 6m 57s
# 198:	total: 4m 34s	remaining: 6m 55s
# 199:	total: 4m 36s	remaining: 6m 54s
# 200:	total: 4m 37s	remaining: 6m 52s
# 201:	total: 4m 38s	remaining: 6m 51s
# 202:	total: 4m 40s	remaining: 6m 49s
# 203:	total: 4m 41s	remaining: 6m 48s
# 204:	total: 4m 43s	remaining: 6m 48s
# 205:	total: 4m 45s	remaining: 6m 47s
# 206:	total: 4m 47s	remaining: 6m 46s
# 207:	total: 4m 49s	remaining: 6m 46s
# 208:	total: 4m 50s	remaining: 6m 44s
# 209:	total: 4m 52s	remaining: 6m 43s
# 210:	total: 4m 54s	remaining: 6m 42s
# 211:	total: 4m 55s	remaining: 6m 41s
# 212:	total: 4m 57s	remaining: 6m 40s
# 213:	total: 4m 58s	remaining: 6m 39s
# 214:	total: 5m	remaining: 6m 38s
# 215:	total: 5m 2s	remaining: 6m 37s
# 216:	total: 5m 3s	remaining: 6m 35s
# 217:	total: 5m 5s	remaining: 6m 34s
# 218:	total: 5m 7s	remaining: 6m 34s
# 219:	total: 5m 9s	remaining: 6m 33s
# 220:	total: 5m 11s	remaining: 6m 32s
# 221:	total: 5m 13s	remaining: 6m 32s
# 222:	total: 5m 15s	remaining: 6m 32s
# 223:	total: 5m 17s	remaining: 6m 31s
# 224:	total: 5m 19s	remaining: 6m 30s
# 225:	total: 5m 21s	remaining: 6m 29s
# 226:	total: 5m 23s	remaining: 6m 28s
# 227:	total: 5m 25s	remaining: 6m 27s
# 228:	total: 5m 26s	remaining: 6m 26s
# 229:	total: 5m 28s	remaining: 6m 25s
# 230:	total: 5m 30s	remaining: 6m 24s
# 231:	total: 5m 31s	remaining: 6m 23s
# 232:	total: 5m 33s	remaining: 6m 22s
# 233:	total: 5m 35s	remaining: 6m 21s
# 234:	total: 5m 37s	remaining: 6m 20s
# 235:	total: 5m 38s	remaining: 6m 19s
# 236:	total: 5m 40s	remaining: 6m 18s
# 237:	total: 5m 42s	remaining: 6m 17s
# 238:	total: 5m 44s	remaining: 6m 16s
# 239:	total: 5m 46s	remaining: 6m 15s
# 240:	total: 5m 48s	remaining: 6m 14s
# 241:	total: 5m 49s	remaining: 6m 12s
# 242:	total: 5m 51s	remaining: 6m 11s
# 243:	total: 5m 53s	remaining: 6m 10s
# 244:	total: 5m 54s	remaining: 6m 9s
# 245:	total: 5m 56s	remaining: 6m 7s
# 246:	total: 5m 57s	remaining: 6m 6s
# 247:	total: 5m 59s	remaining: 6m 5s
# 248:	total: 6m 1s	remaining: 6m 4s
# 249:	total: 6m 2s	remaining: 6m 2s
# 250:	total: 6m 4s	remaining: 6m 1s
# 251:	total: 6m 6s	remaining: 6m
# 252:	total: 6m 7s	remaining: 5m 58s
# 253:	total: 6m 9s	remaining: 5m 57s
# 254:	total: 6m 11s	remaining: 5m 56s
# 255:	total: 6m 13s	remaining: 5m 55s
# 256:	total: 6m 14s	remaining: 5m 54s
# 257:	total: 6m 16s	remaining: 5m 52s
# 258:	total: 6m 17s	remaining: 5m 51s
# 259:	total: 6m 19s	remaining: 5m 50s
# 260:	total: 6m 21s	remaining: 5m 48s
# 261:	total: 6m 22s	remaining: 5m 47s
# 262:	total: 6m 24s	remaining: 5m 46s
# 263:	total: 6m 26s	remaining: 5m 45s
# 264:	total: 6m 27s	remaining: 5m 43s
# 265:	total: 6m 29s	remaining: 5m 42s
# 266:	total: 6m 31s	remaining: 5m 41s
# 267:	total: 6m 33s	remaining: 5m 40s
# 268:	total: 6m 35s	remaining: 5m 39s
# 269:	total: 6m 36s	remaining: 5m 38s
# 270:	total: 6m 38s	remaining: 5m 36s
# 271:	total: 6m 40s	remaining: 5m 36s
# 272:	total: 6m 43s	remaining: 5m 35s
# 273:	total: 6m 45s	remaining: 5m 34s
# 274:	total: 6m 47s	remaining: 5m 33s
# 275:	total: 6m 49s	remaining: 5m 32s
# 276:	total: 6m 51s	remaining: 5m 31s
# 277:	total: 6m 53s	remaining: 5m 29s
# 278:	total: 6m 55s	remaining: 5m 28s
# 279:	total: 6m 56s	remaining: 5m 27s
# 280:	total: 6m 58s	remaining: 5m 26s
# 281:	total: 7m	remaining: 5m 25s
# 282:	total: 7m 2s	remaining: 5m 24s
# 283:	total: 7m 5s	remaining: 5m 23s
# 284:	total: 7m 6s	remaining: 5m 21s
# 285:	total: 7m 8s	remaining: 5m 20s
# 286:	total: 7m 10s	remaining: 5m 19s
# 287:	total: 7m 12s	remaining: 5m 18s
# 288:	total: 7m 14s	remaining: 5m 17s
# 289:	total: 7m 15s	remaining: 5m 15s
# 290:	total: 7m 17s	remaining: 5m 14s
# 291:	total: 7m 18s	remaining: 5m 12s
# 292:	total: 7m 20s	remaining: 5m 11s
# 293:	total: 7m 22s	remaining: 5m 9s
# 294:	total: 7m 23s	remaining: 5m 8s
# 295:	total: 7m 25s	remaining: 5m 7s
# 296:	total: 7m 27s	remaining: 5m 5s
# 297:	total: 7m 28s	remaining: 5m 4s
# 298:	total: 7m 30s	remaining: 5m 2s
# 299:	total: 7m 32s	remaining: 5m 1s
# 300:	total: 7m 34s	remaining: 5m
# 301:	total: 7m 36s	remaining: 4m 59s
# 302:	total: 7m 37s	remaining: 4m 57s
# 303:	total: 7m 39s	remaining: 4m 56s
# 304:	total: 7m 41s	remaining: 4m 55s
# 305:	total: 7m 43s	remaining: 4m 53s
# 306:	total: 7m 45s	remaining: 4m 52s
# 307:	total: 7m 46s	remaining: 4m 50s
# 308:	total: 7m 48s	remaining: 4m 49s
# 309:	total: 7m 49s	remaining: 4m 48s
# 310:	total: 7m 51s	remaining: 4m 46s
# 311:	total: 7m 53s	remaining: 4m 45s
# 312:	total: 7m 55s	remaining: 4m 43s
# 313:	total: 7m 56s	remaining: 4m 42s
# 314:	total: 7m 58s	remaining: 4m 41s
# 315:	total: 8m	remaining: 4m 39s
# 316:	total: 8m 2s	remaining: 4m 38s
# 317:	total: 8m 3s	remaining: 4m 36s
# 318:	total: 8m 5s	remaining: 4m 35s
# 319:	total: 8m 7s	remaining: 4m 34s
# 320:	total: 8m 8s	remaining: 4m 32s
# 321:	total: 8m 11s	remaining: 4m 31s
# 322:	total: 8m 12s	remaining: 4m 30s
# 323:	total: 8m 14s	remaining: 4m 28s
# 324:	total: 8m 16s	remaining: 4m 27s
# 325:	total: 8m 18s	remaining: 4m 25s
# 326:	total: 8m 20s	remaining: 4m 24s
# 327:	total: 8m 21s	remaining: 4m 23s
# 328:	total: 8m 23s	remaining: 4m 21s
# 329:	total: 8m 25s	remaining: 4m 20s
# 330:	total: 8m 26s	remaining: 4m 18s
# 331:	total: 8m 28s	remaining: 4m 17s
# 332:	total: 8m 30s	remaining: 4m 15s
# 333:	total: 8m 32s	remaining: 4m 14s
# 334:	total: 8m 33s	remaining: 4m 13s
# 335:	total: 8m 35s	remaining: 4m 11s
# 336:	total: 8m 37s	remaining: 4m 10s
# 337:	total: 8m 38s	remaining: 4m 8s
# 338:	total: 8m 41s	remaining: 4m 7s
# 339:	total: 8m 43s	remaining: 4m 6s
# 340:	total: 8m 45s	remaining: 4m 4s
# 341:	total: 8m 46s	remaining: 4m 3s
# 342:	total: 8m 48s	remaining: 4m 1s
# 343:	total: 8m 50s	remaining: 4m
# 344:	total: 8m 51s	remaining: 3m 58s
# 345:	total: 8m 53s	remaining: 3m 57s
# 346:	total: 8m 55s	remaining: 3m 56s
# 347:	total: 8m 57s	remaining: 3m 54s
# 348:	total: 8m 58s	remaining: 3m 53s
# 349:	total: 9m	remaining: 3m 51s
# 350:	total: 9m 2s	remaining: 3m 50s
# 351:	total: 9m 4s	remaining: 3m 48s
# 352:	total: 9m 6s	remaining: 3m 47s
# 353:	total: 9m 8s	remaining: 3m 46s
# 354:	total: 9m 10s	remaining: 3m 44s
# 355:	total: 9m 12s	remaining: 3m 43s
# 356:	total: 9m 14s	remaining: 3m 42s
# 357:	total: 9m 16s	remaining: 3m 40s
# 358:	total: 9m 17s	remaining: 3m 39s
# 359:	total: 9m 19s	remaining: 3m 37s
# 360:	total: 9m 21s	remaining: 3m 36s
# 361:	total: 9m 22s	remaining: 3m 34s
# 362:	total: 9m 24s	remaining: 3m 33s
# 363:	total: 9m 26s	remaining: 3m 31s
# 364:	total: 9m 27s	remaining: 3m 30s
# 365:	total: 9m 29s	remaining: 3m 28s
# 366:	total: 9m 31s	remaining: 3m 27s
# 367:	total: 9m 32s	remaining: 3m 25s
# 368:	total: 9m 34s	remaining: 3m 24s
# 369:	total: 9m 36s	remaining: 3m 22s
# 370:	total: 9m 37s	remaining: 3m 20s
# 371:	total: 9m 39s	remaining: 3m 19s
# 372:	total: 9m 41s	remaining: 3m 17s
# 373:	total: 9m 43s	remaining: 3m 16s
# 374:	total: 9m 45s	remaining: 3m 15s
# 375:	total: 9m 47s	remaining: 3m 13s
# 376:	total: 9m 49s	remaining: 3m 12s
# 377:	total: 9m 51s	remaining: 3m 10s
# 378:	total: 9m 53s	remaining: 3m 9s
# 379:	total: 9m 54s	remaining: 3m 7s
# 380:	total: 9m 56s	remaining: 3m 6s
# 381:	total: 9m 58s	remaining: 3m 4s
# 382:	total: 9m 59s	remaining: 3m 3s
# 383:	total: 10m 1s	remaining: 3m 1s
# 384:	total: 10m 3s	remaining: 3m
# 385:	total: 10m 4s	remaining: 2m 58s
# 386:	total: 10m 6s	remaining: 2m 57s
# 387:	total: 10m 8s	remaining: 2m 55s
# 388:	total: 10m 9s	remaining: 2m 54s
# 389:	total: 10m 11s	remaining: 2m 52s
# 390:	total: 10m 14s	remaining: 2m 51s
# 391:	total: 10m 15s	remaining: 2m 49s
# 392:	total: 10m 17s	remaining: 2m 48s
# 393:	total: 10m 19s	remaining: 2m 46s
# 394:	total: 10m 20s	remaining: 2m 45s
# 395:	total: 10m 22s	remaining: 2m 43s
# 396:	total: 10m 24s	remaining: 2m 42s
# 397:	total: 10m 26s	remaining: 2m 40s
# 398:	total: 10m 28s	remaining: 2m 39s
# 399:	total: 10m 30s	remaining: 2m 37s
# 400:	total: 10m 33s	remaining: 2m 36s
# 401:	total: 10m 35s	remaining: 2m 34s
# 402:	total: 10m 36s	remaining: 2m 33s
# 403:	total: 10m 38s	remaining: 2m 31s
# 404:	total: 10m 40s	remaining: 2m 30s
# 405:	total: 10m 42s	remaining: 2m 28s
# 406:	total: 10m 44s	remaining: 2m 27s
# 407:	total: 10m 45s	remaining: 2m 25s
# 408:	total: 10m 47s	remaining: 2m 24s
# 409:	total: 10m 49s	remaining: 2m 22s
# 410:	total: 10m 50s	remaining: 2m 20s
# 411:	total: 10m 52s	remaining: 2m 19s
# 412:	total: 10m 53s	remaining: 2m 17s
# 413:	total: 10m 55s	remaining: 2m 16s
# 414:	total: 10m 56s	remaining: 2m 14s
# 415:	total: 10m 58s	remaining: 2m 12s
# 416:	total: 11m	remaining: 2m 11s
# 417:	total: 11m 1s	remaining: 2m 9s
# 418:	total: 11m 3s	remaining: 2m 8s
# 419:	total: 11m 4s	remaining: 2m 6s
# 420:	total: 11m 6s	remaining: 2m 5s
# 421:	total: 11m 8s	remaining: 2m 3s
# 422:	total: 11m 9s	remaining: 2m 1s
# 423:	total: 11m 12s	remaining: 2m
# 424:	total: 11m 14s	remaining: 1m 58s
# 425:	total: 11m 15s	remaining: 1m 57s
# 426:	total: 11m 17s	remaining: 1m 55s
# 427:	total: 11m 19s	remaining: 1m 54s
# 428:	total: 11m 20s	remaining: 1m 52s
# 429:	total: 11m 22s	remaining: 1m 51s
# 430:	total: 11m 24s	remaining: 1m 49s
# 431:	total: 11m 25s	remaining: 1m 47s
# 432:	total: 11m 27s	remaining: 1m 46s
# 433:	total: 11m 29s	remaining: 1m 44s
# 434:	total: 11m 31s	remaining: 1m 43s
# 435:	total: 11m 32s	remaining: 1m 41s
# 436:	total: 11m 34s	remaining: 1m 40s
# 437:	total: 11m 36s	remaining: 1m 38s
# 438:	total: 11m 37s	remaining: 1m 36s
# 439:	total: 11m 39s	remaining: 1m 35s
# 440:	total: 11m 41s	remaining: 1m 33s
# 441:	total: 11m 43s	remaining: 1m 32s
# 442:	total: 11m 45s	remaining: 1m 30s
# 443:	total: 11m 46s	remaining: 1m 29s
# 444:	total: 11m 48s	remaining: 1m 27s
# 445:	total: 11m 49s	remaining: 1m 25s
# 446:	total: 11m 51s	remaining: 1m 24s
# 447:	total: 11m 53s	remaining: 1m 22s
# 448:	total: 11m 55s	remaining: 1m 21s
# 449:	total: 11m 56s	remaining: 1m 19s
# 450:	total: 11m 58s	remaining: 1m 18s
# 451:	total: 12m	remaining: 1m 16s
# 452:	total: 12m 1s	remaining: 1m 14s
# 453:	total: 12m 3s	remaining: 1m 13s
# 454:	total: 12m 5s	remaining: 1m 11s
# 455:	total: 12m 6s	remaining: 1m 10s
# 456:	total: 12m 8s	remaining: 1m 8s
# 457:	total: 12m 10s	remaining: 1m 6s
# 458:	total: 12m 12s	remaining: 1m 5s
# 459:	total: 12m 13s	remaining: 1m 3s
# 460:	total: 12m 15s	remaining: 1m 2s
# 461:	total: 12m 17s	remaining: 1m
# 462:	total: 12m 19s	remaining: 59.1s
# 463:	total: 12m 20s	remaining: 57.5s
# 464:	total: 12m 22s	remaining: 55.9s
# 465:	total: 12m 24s	remaining: 54.3s
# 466:	total: 12m 25s	remaining: 52.7s
# 467:	total: 12m 27s	remaining: 51.1s
# 468:	total: 12m 28s	remaining: 49.5s
# 469:	total: 12m 30s	remaining: 47.9s
# 470:	total: 12m 32s	remaining: 46.3s
# 471:	total: 12m 34s	remaining: 44.7s
# 472:	total: 12m 35s	remaining: 43.1s
# 473:	total: 12m 37s	remaining: 41.5s
# 474:	total: 12m 38s	remaining: 39.9s
# 475:	total: 12m 40s	remaining: 38.4s
# 476:	total: 12m 42s	remaining: 36.8s
# 477:	total: 12m 44s	remaining: 35.2s
# 478:	total: 12m 46s	remaining: 33.6s
# 479:	total: 12m 47s	remaining: 32s
# 480:	total: 12m 49s	remaining: 30.4s
# 481:	total: 12m 50s	remaining: 28.8s
# 482:	total: 12m 52s	remaining: 27.2s
# 483:	total: 12m 54s	remaining: 25.6s
# 484:	total: 12m 55s	remaining: 24s
# 485:	total: 12m 57s	remaining: 22.4s
# 486:	total: 12m 58s	remaining: 20.8s
# 487:	total: 13m	remaining: 19.2s
# 488:	total: 13m 3s	remaining: 17.6s
# 489:	total: 13m 5s	remaining: 16s
# 490:	total: 13m 7s	remaining: 14.4s
# 491:	total: 13m 10s	remaining: 12.8s
# 492:	total: 13m 13s	remaining: 11.3s
# 493:	total: 13m 15s	remaining: 9.66s
# 494:	total: 13m 17s	remaining: 8.05s
# 495:	total: 13m 19s	remaining: 6.44s
# 496:	total: 13m 20s	remaining: 4.83s
# 497:	total: 13m 22s	remaining: 3.22s
# 498:	total: 13m 24s	remaining: 1.61s
# 499:	total: 13m 25s	remaining: 0us
# 0:	total: 1.93s	remaining: 16m
# 1:	total: 3.8s	remaining: 15m 47s
# 2:	total: 5.36s	remaining: 14m 47s
# 3:	total: 6.92s	remaining: 14m 18s
# 4:	total: 8.48s	remaining: 13m 59s
# 5:	total: 9.95s	remaining: 13m 39s
# 6:	total: 11.5s	remaining: 13m 28s
# 7:	total: 13.1s	remaining: 13m 23s
# 8:	total: 14.8s	remaining: 13m 25s
# 9:	total: 16.4s	remaining: 13m 22s
# 10:	total: 17.9s	remaining: 13m 17s
# 11:	total: 19.5s	remaining: 13m 11s
# 12:	total: 21s	remaining: 13m 5s
# 13:	total: 22.6s	remaining: 13m 4s
# 14:	total: 24.3s	remaining: 13m 5s
# 15:	total: 26s	remaining: 13m 7s
# 16:	total: 27.9s	remaining: 13m 12s
# 17:	total: 30s	remaining: 13m 22s
# 18:	total: 32s	remaining: 13m 30s
# 19:	total: 34s	remaining: 13m 35s
# 20:	total: 35.5s	remaining: 13m 29s
# 21:	total: 37s	remaining: 13m 23s
# 22:	total: 38.6s	remaining: 13m 20s
# 23:	total: 40.2s	remaining: 13m 16s
# 24:	total: 41.8s	remaining: 13m 14s
# 25:	total: 43.4s	remaining: 13m 10s
# 26:	total: 45s	remaining: 13m 7s
# 27:	total: 46.6s	remaining: 13m 4s
# 28:	total: 48s	remaining: 12m 59s
# 29:	total: 49.5s	remaining: 12m 55s
# 30:	total: 51.1s	remaining: 12m 52s
# 31:	total: 52.8s	remaining: 12m 52s
# 32:	total: 54.5s	remaining: 12m 50s
# 33:	total: 56s	remaining: 12m 47s
# 34:	total: 57.5s	remaining: 12m 44s
# 35:	total: 59.2s	remaining: 12m 43s
# 36:	total: 1m 1s	remaining: 12m 45s
# 37:	total: 1m 2s	remaining: 12m 45s
# 38:	total: 1m 4s	remaining: 12m 43s
# 39:	total: 1m 6s	remaining: 12m 40s
# 40:	total: 1m 7s	remaining: 12m 37s
# 41:	total: 1m 9s	remaining: 12m 35s
# 42:	total: 1m 10s	remaining: 12m 32s
# 43:	total: 1m 12s	remaining: 12m 29s
# 44:	total: 1m 13s	remaining: 12m 27s
# 45:	total: 1m 15s	remaining: 12m 24s
# 46:	total: 1m 16s	remaining: 12m 22s
# 47:	total: 1m 18s	remaining: 12m 19s
# 48:	total: 1m 20s	remaining: 12m 16s
# 49:	total: 1m 21s	remaining: 12m 14s
# 50:	total: 1m 23s	remaining: 12m 12s
# 51:	total: 1m 24s	remaining: 12m 10s
# 52:	total: 1m 26s	remaining: 12m 9s
# 53:	total: 1m 28s	remaining: 12m 8s
# 54:	total: 1m 30s	remaining: 12m 8s
# 55:	total: 1m 32s	remaining: 12m 9s
# 56:	total: 1m 33s	remaining: 12m 9s
# 57:	total: 1m 35s	remaining: 12m 7s
# 58:	total: 1m 37s	remaining: 12m 5s
# 59:	total: 1m 38s	remaining: 12m 3s
# 60:	total: 1m 40s	remaining: 12m 1s
# 61:	total: 1m 41s	remaining: 11m 59s
# 62:	total: 1m 43s	remaining: 11m 56s
# 63:	total: 1m 44s	remaining: 11m 54s
# 64:	total: 1m 46s	remaining: 11m 52s
# 65:	total: 1m 47s	remaining: 11m 50s
# 66:	total: 1m 49s	remaining: 11m 47s
# 67:	total: 1m 51s	remaining: 11m 46s
# 68:	total: 1m 52s	remaining: 11m 44s
# 69:	total: 1m 54s	remaining: 11m 43s
# 70:	total: 1m 56s	remaining: 11m 41s
# 71:	total: 1m 57s	remaining: 11m 39s
# 72:	total: 1m 59s	remaining: 11m 38s
# 73:	total: 2m 1s	remaining: 11m 38s
# 74:	total: 2m 3s	remaining: 11m 37s
# 75:	total: 2m 4s	remaining: 11m 35s
# 76:	total: 2m 6s	remaining: 11m 33s
# 77:	total: 2m 7s	remaining: 11m 32s
# 78:	total: 2m 9s	remaining: 11m 31s
# 79:	total: 2m 11s	remaining: 11m 30s
# 80:	total: 2m 13s	remaining: 11m 29s
# 81:	total: 2m 15s	remaining: 11m 28s
# 82:	total: 2m 16s	remaining: 11m 26s
# 83:	total: 2m 18s	remaining: 11m 24s
# 84:	total: 2m 19s	remaining: 11m 22s
# 85:	total: 2m 21s	remaining: 11m 20s
# 86:	total: 2m 23s	remaining: 11m 19s
# 87:	total: 2m 24s	remaining: 11m 18s
# 88:	total: 2m 26s	remaining: 11m 16s
# 89:	total: 2m 28s	remaining: 11m 14s
# 90:	total: 2m 29s	remaining: 11m 13s
# 91:	total: 2m 31s	remaining: 11m 13s
# 92:	total: 2m 33s	remaining: 11m 12s
# 93:	total: 2m 35s	remaining: 11m 10s
# 94:	total: 2m 36s	remaining: 11m 8s
# 95:	total: 2m 38s	remaining: 11m 6s
# 96:	total: 2m 40s	remaining: 11m 5s
# 97:	total: 2m 41s	remaining: 11m 3s
# 98:	total: 2m 43s	remaining: 11m 3s
# 99:	total: 2m 45s	remaining: 11m 2s
# 100:	total: 2m 47s	remaining: 11m
# 101:	total: 2m 48s	remaining: 10m 58s
# 102:	total: 2m 50s	remaining: 10m 56s
# 103:	total: 2m 51s	remaining: 10m 54s
# 104:	total: 2m 53s	remaining: 10m 52s
# 105:	total: 2m 55s	remaining: 10m 51s
# 106:	total: 2m 56s	remaining: 10m 49s
# 107:	total: 2m 58s	remaining: 10m 47s
# 108:	total: 3m	remaining: 10m 46s
# 109:	total: 3m 2s	remaining: 10m 45s
# 110:	total: 3m 3s	remaining: 10m 44s
# 111:	total: 3m 5s	remaining: 10m 42s
# 112:	total: 3m 7s	remaining: 10m 40s
# 113:	total: 3m 8s	remaining: 10m 39s
# 114:	total: 3m 10s	remaining: 10m 37s
# 115:	total: 3m 11s	remaining: 10m 35s
# 116:	total: 3m 13s	remaining: 10m 34s
# 117:	total: 3m 15s	remaining: 10m 32s
# 118:	total: 3m 16s	remaining: 10m 29s
# 119:	total: 3m 18s	remaining: 10m 27s
# 120:	total: 3m 19s	remaining: 10m 25s
# 121:	total: 3m 21s	remaining: 10m 23s
# 122:	total: 3m 22s	remaining: 10m 21s
# 123:	total: 3m 24s	remaining: 10m 19s
# 124:	total: 3m 26s	remaining: 10m 18s
# 125:	total: 3m 27s	remaining: 10m 16s
# 126:	total: 3m 29s	remaining: 10m 14s
# 127:	total: 3m 31s	remaining: 10m 14s
# 128:	total: 3m 33s	remaining: 10m 12s
# 129:	total: 3m 34s	remaining: 10m 11s
# 130:	total: 3m 36s	remaining: 10m 9s
# 131:	total: 3m 37s	remaining: 10m 7s
# 132:	total: 3m 39s	remaining: 10m 5s
# 133:	total: 3m 40s	remaining: 10m 3s
# 134:	total: 3m 42s	remaining: 10m 1s
# 135:	total: 3m 44s	remaining: 9m 59s
# 136:	total: 3m 45s	remaining: 9m 58s
# 137:	total: 3m 47s	remaining: 9m 56s
# 138:	total: 3m 48s	remaining: 9m 54s
# 139:	total: 3m 50s	remaining: 9m 52s
# 140:	total: 3m 51s	remaining: 9m 50s
# 141:	total: 3m 53s	remaining: 9m 49s
# 142:	total: 3m 55s	remaining: 9m 47s
# 143:	total: 3m 57s	remaining: 9m 46s
# 144:	total: 3m 58s	remaining: 9m 44s
# 145:	total: 4m	remaining: 9m 42s
# 146:	total: 4m 2s	remaining: 9m 42s
# 147:	total: 4m 4s	remaining: 9m 41s
# 148:	total: 4m 6s	remaining: 9m 39s
# 149:	total: 4m 7s	remaining: 9m 37s
# 150:	total: 4m 9s	remaining: 9m 35s
# 151:	total: 4m 10s	remaining: 9m 34s
# 152:	total: 4m 12s	remaining: 9m 32s
# 153:	total: 4m 14s	remaining: 9m 31s
# 154:	total: 4m 16s	remaining: 9m 29s
# 155:	total: 4m 17s	remaining: 9m 28s
# 156:	total: 4m 19s	remaining: 9m 26s
# 157:	total: 4m 20s	remaining: 9m 24s
# 158:	total: 4m 22s	remaining: 9m 22s
# 159:	total: 4m 23s	remaining: 9m 20s
# 160:	total: 4m 25s	remaining: 9m 18s
# 161:	total: 4m 26s	remaining: 9m 16s
# 162:	total: 4m 28s	remaining: 9m 14s
# 163:	total: 4m 29s	remaining: 9m 12s
# 164:	total: 4m 31s	remaining: 9m 11s
# 165:	total: 4m 33s	remaining: 9m 10s
# 166:	total: 4m 34s	remaining: 9m 8s
# 167:	total: 4m 36s	remaining: 9m 5s
# 168:	total: 4m 37s	remaining: 9m 3s
# 169:	total: 4m 38s	remaining: 9m 1s
# 170:	total: 4m 40s	remaining: 8m 59s
# 171:	total: 4m 41s	remaining: 8m 57s
# 172:	total: 4m 43s	remaining: 8m 55s
# 173:	total: 4m 44s	remaining: 8m 53s
# 174:	total: 4m 46s	remaining: 8m 51s
# 175:	total: 4m 47s	remaining: 8m 49s
# 176:	total: 4m 48s	remaining: 8m 46s
# 177:	total: 4m 50s	remaining: 8m 44s
# 178:	total: 4m 51s	remaining: 8m 42s
# 179:	total: 4m 52s	remaining: 8m 40s
# 180:	total: 4m 54s	remaining: 8m 38s
# 181:	total: 4m 55s	remaining: 8m 36s
# 182:	total: 4m 56s	remaining: 8m 34s
# 183:	total: 4m 58s	remaining: 8m 32s
# 184:	total: 4m 59s	remaining: 8m 30s
# 185:	total: 5m 1s	remaining: 8m 28s
# 186:	total: 5m 2s	remaining: 8m 26s
# 187:	total: 5m 4s	remaining: 8m 24s
# 188:	total: 5m 6s	remaining: 8m 23s
# 189:	total: 5m 7s	remaining: 8m 22s
# 190:	total: 5m 9s	remaining: 8m 20s
# 191:	total: 5m 10s	remaining: 8m 18s
# 192:	total: 5m 11s	remaining: 8m 15s
# 193:	total: 5m 13s	remaining: 8m 13s
# 194:	total: 5m 14s	remaining: 8m 11s
# 195:	total: 5m 15s	remaining: 8m 9s
# 196:	total: 5m 17s	remaining: 8m 7s
# 197:	total: 5m 18s	remaining: 8m 5s
# 198:	total: 5m 19s	remaining: 8m 3s
# 199:	total: 5m 21s	remaining: 8m 2s
# 200:	total: 5m 23s	remaining: 8m
# 201:	total: 5m 24s	remaining: 7m 59s
# 202:	total: 5m 26s	remaining: 7m 57s
# 203:	total: 5m 28s	remaining: 7m 56s
# 204:	total: 5m 30s	remaining: 7m 55s
# 205:	total: 5m 32s	remaining: 7m 54s
# 206:	total: 5m 34s	remaining: 7m 53s
# 207:	total: 5m 35s	remaining: 7m 51s
# 208:	total: 5m 37s	remaining: 7m 49s
# 209:	total: 5m 38s	remaining: 7m 47s
# 210:	total: 5m 40s	remaining: 7m 45s
# 211:	total: 5m 41s	remaining: 7m 44s
# 212:	total: 5m 43s	remaining: 7m 42s
# 213:	total: 5m 44s	remaining: 7m 41s
# 214:	total: 5m 46s	remaining: 7m 39s
# 215:	total: 5m 48s	remaining: 7m 37s
# 216:	total: 5m 49s	remaining: 7m 35s
# 217:	total: 5m 51s	remaining: 7m 34s
# 218:	total: 5m 52s	remaining: 7m 32s
# 219:	total: 5m 54s	remaining: 7m 30s
# 220:	total: 5m 55s	remaining: 7m 29s
# 221:	total: 5m 57s	remaining: 7m 27s
# 222:	total: 5m 59s	remaining: 7m 26s
# 223:	total: 6m 1s	remaining: 7m 25s
# 224:	total: 6m 2s	remaining: 7m 23s
# 225:	total: 6m 4s	remaining: 7m 22s
# 226:	total: 6m 6s	remaining: 7m 20s
# 227:	total: 6m 8s	remaining: 7m 19s
# 228:	total: 6m 9s	remaining: 7m 17s
# 229:	total: 6m 11s	remaining: 7m 16s
# 230:	total: 6m 13s	remaining: 7m 15s
# 231:	total: 6m 16s	remaining: 7m 14s
# 232:	total: 6m 17s	remaining: 7m 12s
# 233:	total: 6m 19s	remaining: 7m 11s
# 234:	total: 6m 21s	remaining: 7m 9s
# 235:	total: 6m 22s	remaining: 7m 8s
# 236:	total: 6m 24s	remaining: 7m 6s
# 237:	total: 6m 25s	remaining: 7m 4s
# 238:	total: 6m 26s	remaining: 7m 2s
# 239:	total: 6m 28s	remaining: 7m
# 240:	total: 6m 29s	remaining: 6m 58s
# 241:	total: 6m 31s	remaining: 6m 56s
# 242:	total: 6m 32s	remaining: 6m 55s
# 243:	total: 6m 33s	remaining: 6m 53s
# 244:	total: 6m 35s	remaining: 6m 51s
# 245:	total: 6m 36s	remaining: 6m 49s
# 246:	total: 6m 37s	remaining: 6m 47s
# 247:	total: 6m 39s	remaining: 6m 45s
# 248:	total: 6m 41s	remaining: 6m 44s
# 249:	total: 6m 43s	remaining: 6m 43s
# 250:	total: 6m 45s	remaining: 6m 42s
# 251:	total: 6m 47s	remaining: 6m 40s
# 252:	total: 6m 49s	remaining: 6m 39s
# 253:	total: 6m 50s	remaining: 6m 37s
# 254:	total: 6m 52s	remaining: 6m 36s
# 255:	total: 6m 54s	remaining: 6m 34s
# 256:	total: 6m 55s	remaining: 6m 33s
# 257:	total: 6m 57s	remaining: 6m 31s
# 258:	total: 6m 58s	remaining: 6m 29s
# 259:	total: 7m	remaining: 6m 27s
# 260:	total: 7m 1s	remaining: 6m 26s
# 261:	total: 7m 3s	remaining: 6m 24s
# 262:	total: 7m 4s	remaining: 6m 22s
# 263:	total: 7m 5s	remaining: 6m 20s
# 264:	total: 7m 6s	remaining: 6m 18s
# 265:	total: 7m 8s	remaining: 6m 16s
# 266:	total: 7m 9s	remaining: 6m 14s
# 267:	total: 7m 10s	remaining: 6m 12s
# 268:	total: 7m 12s	remaining: 6m 11s
# 269:	total: 7m 13s	remaining: 6m 9s
# 270:	total: 7m 14s	remaining: 6m 7s
# 271:	total: 7m 15s	remaining: 6m 5s
# 272:	total: 7m 17s	remaining: 6m 3s
# 273:	total: 7m 18s	remaining: 6m 1s
# 274:	total: 7m 20s	remaining: 6m
# 275:	total: 7m 21s	remaining: 5m 58s
# 276:	total: 7m 22s	remaining: 5m 56s
# 277:	total: 7m 24s	remaining: 5m 54s
# 278:	total: 7m 25s	remaining: 5m 52s
# 279:	total: 7m 26s	remaining: 5m 51s
# 280:	total: 7m 28s	remaining: 5m 49s
# 281:	total: 7m 29s	remaining: 5m 47s
# 282:	total: 7m 30s	remaining: 5m 45s
# 283:	total: 7m 32s	remaining: 5m 44s
# 284:	total: 7m 33s	remaining: 5m 42s
# 285:	total: 7m 35s	remaining: 5m 40s
# 286:	total: 7m 36s	remaining: 5m 39s
# 287:	total: 7m 38s	remaining: 5m 37s
# 288:	total: 7m 40s	remaining: 5m 36s
# 289:	total: 7m 42s	remaining: 5m 34s
# 290:	total: 7m 43s	remaining: 5m 32s
# 291:	total: 7m 44s	remaining: 5m 31s
# 292:	total: 7m 46s	remaining: 5m 29s
# 293:	total: 7m 47s	remaining: 5m 27s
# 294:	total: 7m 48s	remaining: 5m 25s
# 295:	total: 7m 50s	remaining: 5m 24s
# 296:	total: 7m 51s	remaining: 5m 22s
# 297:	total: 7m 52s	remaining: 5m 20s
# 298:	total: 7m 54s	remaining: 5m 18s
# 299:	total: 7m 55s	remaining: 5m 17s
# 300:	total: 7m 57s	remaining: 5m 15s
# 301:	total: 7m 58s	remaining: 5m 13s
# 302:	total: 7m 59s	remaining: 5m 11s
# 303:	total: 8m 1s	remaining: 5m 10s
# 304:	total: 8m 2s	remaining: 5m 8s
# 305:	total: 8m 3s	remaining: 5m 6s
# 306:	total: 8m 5s	remaining: 5m 5s
# 307:	total: 8m 6s	remaining: 5m 3s
# 308:	total: 8m 8s	remaining: 5m 1s
# 309:	total: 8m 9s	remaining: 5m
# 310:	total: 8m 11s	remaining: 4m 58s
# 311:	total: 8m 12s	remaining: 4m 56s
# ...
# 70:	total: 2m 7s	remaining: 12m 48s
# 71:	total: 2m 9s	remaining: 12m 47s
# 72:	total: 2m 10s	remaining: 12m 45s
# 73:	total: 2m 12s	remaining: 12m 43s
# 74:	total: 2m 14s	remaining: 12m 41s
# 75:	total: 2m 16s	remaining: 12m 40s
# 76:	total: 2m 18s	remaining: 12m 38s
# 77:	total: 2m 20s	remaining: 12m 37s
# 78:	total: 2m 22s	remaining: 12m 36s
# 79:	total: 2m 23s	remaining: 12m 35s
# 80:	total: 2m 25s	remaining: 12m 33s
# 81:	total: 2m 27s	remaining: 12m 32s
# 82:	total: 2m 29s	remaining: 12m 31s
# 83:	total: 2m 31s	remaining: 12m 28s
# 84:	total: 2m 32s	remaining: 12m 25s
# 85:	total: 2m 34s	remaining: 12m 22s
# 86:	total: 2m 35s	remaining: 12m 20s
# 87:	total: 2m 37s	remaining: 12m 17s
# 88:	total: 2m 39s	remaining: 12m 14s
# 89:	total: 2m 40s	remaining: 12m 12s
# 90:	total: 2m 42s	remaining: 12m 10s
# 91:	total: 2m 44s	remaining: 12m 7s
# 92:	total: 2m 45s	remaining: 12m 5s
# 93:	total: 2m 47s	remaining: 12m 3s
# 94:	total: 2m 49s	remaining: 12m
# 95:	total: 2m 50s	remaining: 11m 58s
# 96:	total: 2m 52s	remaining: 11m 56s
# 97:	total: 2m 54s	remaining: 11m 53s
# 98:	total: 2m 56s	remaining: 11m 54s
# 99:	total: 2m 58s	remaining: 11m 55s
# 100:	total: 3m	remaining: 11m 54s
# 101:	total: 3m 2s	remaining: 11m 53s
# 102:	total: 3m 4s	remaining: 11m 51s
# 103:	total: 3m 6s	remaining: 11m 49s
# 104:	total: 3m 8s	remaining: 11m 47s
# 105:	total: 3m 9s	remaining: 11m 45s
# 106:	total: 3m 11s	remaining: 11m 42s
# 107:	total: 3m 13s	remaining: 11m 41s
# 108:	total: 3m 14s	remaining: 11m 38s
# 109:	total: 3m 16s	remaining: 11m 36s
# 110:	total: 3m 18s	remaining: 11m 34s
# 111:	total: 3m 19s	remaining: 11m 32s
# 112:	total: 3m 21s	remaining: 11m 30s
# 113:	total: 3m 23s	remaining: 11m 28s
# 114:	total: 3m 24s	remaining: 11m 25s
# 115:	total: 3m 26s	remaining: 11m 23s
# 116:	total: 3m 28s	remaining: 11m 23s
# 117:	total: 3m 30s	remaining: 11m 21s
# 118:	total: 3m 32s	remaining: 11m 19s
# 119:	total: 3m 33s	remaining: 11m 17s
# 120:	total: 3m 35s	remaining: 11m 15s
# 121:	total: 3m 37s	remaining: 11m 13s
# 122:	total: 3m 39s	remaining: 11m 12s
# 123:	total: 3m 40s	remaining: 11m 10s
# 124:	total: 3m 42s	remaining: 11m 7s
# 125:	total: 3m 44s	remaining: 11m 5s
# 126:	total: 3m 45s	remaining: 11m 3s
# 127:	total: 3m 47s	remaining: 11m 1s
# 128:	total: 3m 49s	remaining: 10m 59s
# 129:	total: 3m 50s	remaining: 10m 56s
# 130:	total: 3m 52s	remaining: 10m 54s
# 131:	total: 3m 54s	remaining: 10m 52s
# 132:	total: 3m 55s	remaining: 10m 50s
# 133:	total: 3m 57s	remaining: 10m 49s
# 134:	total: 3m 59s	remaining: 10m 48s
# 135:	total: 4m 1s	remaining: 10m 45s
# 136:	total: 4m 2s	remaining: 10m 43s
# 137:	total: 4m 4s	remaining: 10m 41s
# 138:	total: 4m 6s	remaining: 10m 39s
# 139:	total: 4m 7s	remaining: 10m 37s
# 140:	total: 4m 9s	remaining: 10m 35s
# 141:	total: 4m 11s	remaining: 10m 33s
# 142:	total: 4m 12s	remaining: 10m 31s
# 143:	total: 4m 14s	remaining: 10m 29s
# 144:	total: 4m 16s	remaining: 10m 27s
# 145:	total: 4m 18s	remaining: 10m 25s
# 146:	total: 4m 19s	remaining: 10m 23s
# 147:	total: 4m 21s	remaining: 10m 21s
# 148:	total: 4m 23s	remaining: 10m 20s
# 149:	total: 4m 24s	remaining: 10m 18s
# 150:	total: 4m 26s	remaining: 10m 16s
# 151:	total: 4m 28s	remaining: 10m 15s
# 152:	total: 4m 30s	remaining: 10m 13s
# 153:	total: 4m 32s	remaining: 10m 11s
# 154:	total: 4m 33s	remaining: 10m 9s
# 155:	total: 4m 35s	remaining: 10m 7s
# 156:	total: 4m 37s	remaining: 10m 5s
# 157:	total: 4m 38s	remaining: 10m 3s
# 158:	total: 4m 40s	remaining: 10m 1s
# 159:	total: 4m 41s	remaining: 9m 58s
# 160:	total: 4m 43s	remaining: 9m 56s
# 161:	total: 4m 45s	remaining: 9m 54s
# 162:	total: 4m 46s	remaining: 9m 53s
# 163:	total: 4m 48s	remaining: 9m 51s
# 164:	total: 4m 50s	remaining: 9m 49s
# 165:	total: 4m 51s	remaining: 9m 47s
# 166:	total: 4m 53s	remaining: 9m 45s
# 167:	total: 4m 55s	remaining: 9m 43s
# 168:	total: 4m 56s	remaining: 9m 41s
# 169:	total: 4m 59s	remaining: 9m 40s
# 170:	total: 5m	remaining: 9m 38s
# 171:	total: 5m 2s	remaining: 9m 36s
# 172:	total: 5m 4s	remaining: 9m 34s
# 173:	total: 5m 5s	remaining: 9m 32s
# 174:	total: 5m 7s	remaining: 9m 31s
# 175:	total: 5m 9s	remaining: 9m 29s
# 176:	total: 5m 10s	remaining: 9m 27s
# 177:	total: 5m 12s	remaining: 9m 24s
# 178:	total: 5m 13s	remaining: 9m 23s
# 179:	total: 5m 15s	remaining: 9m 21s
# 180:	total: 5m 18s	remaining: 9m 21s
# 181:	total: 5m 20s	remaining: 9m 20s
# 182:	total: 5m 22s	remaining: 9m 19s
# 183:	total: 5m 24s	remaining: 9m 17s
# 184:	total: 5m 26s	remaining: 9m 15s
# 185:	total: 5m 28s	remaining: 9m 14s
# 186:	total: 5m 30s	remaining: 9m 12s
# 187:	total: 5m 31s	remaining: 9m 10s
# 188:	total: 5m 33s	remaining: 9m 8s
# 189:	total: 5m 35s	remaining: 9m 6s
# 190:	total: 5m 36s	remaining: 9m 4s
# 191:	total: 5m 38s	remaining: 9m 2s
# 192:	total: 5m 39s	remaining: 9m
# 193:	total: 5m 42s	remaining: 8m 59s
# 194:	total: 5m 44s	remaining: 8m 58s
# 195:	total: 5m 46s	remaining: 8m 56s
# 196:	total: 5m 47s	remaining: 8m 54s
# 197:	total: 5m 49s	remaining: 8m 52s
# 198:	total: 5m 50s	remaining: 8m 50s
# 199:	total: 5m 52s	remaining: 8m 48s
# 200:	total: 5m 53s	remaining: 8m 45s
# 201:	total: 5m 55s	remaining: 8m 43s
# 202:	total: 5m 56s	remaining: 8m 41s
# 203:	total: 5m 58s	remaining: 8m 40s
# 204:	total: 6m	remaining: 8m 38s
# 205:	total: 6m 2s	remaining: 8m 36s
# 206:	total: 6m 3s	remaining: 8m 34s
# 207:	total: 6m 5s	remaining: 8m 32s
# 208:	total: 6m 6s	remaining: 8m 30s
# 209:	total: 6m 8s	remaining: 8m 28s
# 210:	total: 6m 9s	remaining: 8m 26s
# 211:	total: 6m 11s	remaining: 8m 24s
# 212:	total: 6m 12s	remaining: 8m 22s
# 213:	total: 6m 14s	remaining: 8m 20s
# 214:	total: 6m 15s	remaining: 8m 18s
# 215:	total: 6m 17s	remaining: 8m 16s
# 216:	total: 6m 18s	remaining: 8m 14s
# 217:	total: 6m 20s	remaining: 8m 12s
# 218:	total: 6m 21s	remaining: 8m 10s
# 219:	total: 6m 23s	remaining: 8m 8s
# 220:	total: 6m 24s	remaining: 8m 5s
# 221:	total: 6m 26s	remaining: 8m 4s
# 222:	total: 6m 28s	remaining: 8m 2s
# 223:	total: 6m 30s	remaining: 8m
# 224:	total: 6m 31s	remaining: 7m 58s
# 225:	total: 6m 33s	remaining: 7m 56s
# 226:	total: 6m 34s	remaining: 7m 54s
# 227:	total: 6m 35s	remaining: 7m 52s
# 228:	total: 6m 37s	remaining: 7m 50s
# 229:	total: 6m 39s	remaining: 7m 48s
# 230:	total: 6m 40s	remaining: 7m 46s
# 231:	total: 6m 41s	remaining: 7m 44s
# 232:	total: 6m 43s	remaining: 7m 42s
# 233:	total: 6m 45s	remaining: 7m 40s
# 234:	total: 6m 46s	remaining: 7m 38s
# 235:	total: 6m 48s	remaining: 7m 36s
# 236:	total: 6m 49s	remaining: 7m 34s
# 237:	total: 6m 51s	remaining: 7m 32s
# 238:	total: 6m 52s	remaining: 7m 30s
# 239:	total: 6m 54s	remaining: 7m 28s
# 240:	total: 6m 55s	remaining: 7m 27s
# 241:	total: 6m 57s	remaining: 7m 25s
# 242:	total: 6m 59s	remaining: 7m 23s
# 243:	total: 7m 1s	remaining: 7m 21s
# 244:	total: 7m 2s	remaining: 7m 19s
# 245:	total: 7m 4s	remaining: 7m 17s
# 246:	total: 7m 5s	remaining: 7m 15s
# 247:	total: 7m 7s	remaining: 7m 14s
# 248:	total: 7m 8s	remaining: 7m 12s
# 249:	total: 7m 10s	remaining: 7m 10s
# 250:	total: 7m 11s	remaining: 7m 8s
# 251:	total: 7m 13s	remaining: 7m 6s
# 252:	total: 7m 15s	remaining: 7m 4s
# 253:	total: 7m 16s	remaining: 7m 3s
# 254:	total: 7m 18s	remaining: 7m 1s
# 255:	total: 7m 19s	remaining: 6m 59s
# 256:	total: 7m 21s	remaining: 6m 57s
# 257:	total: 7m 23s	remaining: 6m 55s
# 258:	total: 7m 24s	remaining: 6m 53s
# 259:	total: 7m 26s	remaining: 6m 51s
# 260:	total: 7m 28s	remaining: 6m 50s
# 261:	total: 7m 29s	remaining: 6m 48s
# 262:	total: 7m 31s	remaining: 6m 46s
# 263:	total: 7m 33s	remaining: 6m 44s
# 264:	total: 7m 34s	remaining: 6m 43s
# 265:	total: 7m 36s	remaining: 6m 41s
# 266:	total: 7m 37s	remaining: 6m 39s
# 267:	total: 7m 39s	remaining: 6m 37s
# 268:	total: 7m 40s	remaining: 6m 35s
# 269:	total: 7m 42s	remaining: 6m 33s
# 270:	total: 7m 43s	remaining: 6m 31s
# 271:	total: 7m 45s	remaining: 6m 29s
# 272:	total: 7m 46s	remaining: 6m 28s
# 273:	total: 7m 48s	remaining: 6m 26s
# 274:	total: 7m 49s	remaining: 6m 24s
# 275:	total: 7m 51s	remaining: 6m 22s
# 276:	total: 7m 52s	remaining: 6m 20s
# 277:	total: 7m 54s	remaining: 6m 18s
# 278:	total: 7m 55s	remaining: 6m 16s
# 279:	total: 7m 57s	remaining: 6m 15s
# 280:	total: 7m 59s	remaining: 6m 13s
# 281:	total: 8m 1s	remaining: 6m 11s
# 282:	total: 8m 2s	remaining: 6m 10s
# 283:	total: 8m 4s	remaining: 6m 8s
# 284:	total: 8m 5s	remaining: 6m 6s
# 285:	total: 8m 7s	remaining: 6m 4s
# 286:	total: 8m 8s	remaining: 6m 2s
# 287:	total: 8m 10s	remaining: 6m
# 288:	total: 8m 11s	remaining: 5m 58s
# 289:	total: 8m 13s	remaining: 5m 57s
# 290:	total: 8m 14s	remaining: 5m 55s
# 291:	total: 8m 16s	remaining: 5m 53s
# 292:	total: 8m 17s	remaining: 5m 51s
# 293:	total: 8m 19s	remaining: 5m 49s
# 294:	total: 8m 20s	remaining: 5m 48s
# 295:	total: 8m 22s	remaining: 5m 46s
# 296:	total: 8m 23s	remaining: 5m 44s
# 297:	total: 8m 25s	remaining: 5m 42s
# 298:	total: 8m 27s	remaining: 5m 40s
# 299:	total: 8m 28s	remaining: 5m 39s
# 300:	total: 8m 30s	remaining: 5m 37s
# 301:	total: 8m 32s	remaining: 5m 35s
# 302:	total: 8m 33s	remaining: 5m 33s
# 303:	total: 8m 35s	remaining: 5m 32s
# 304:	total: 8m 36s	remaining: 5m 30s
# 305:	total: 8m 38s	remaining: 5m 28s
# 306:	total: 8m 39s	remaining: 5m 26s
# 307:	total: 8m 41s	remaining: 5m 25s
# 308:	total: 8m 42s	remaining: 5m 23s
# 309:	total: 8m 44s	remaining: 5m 21s
# 310:	total: 8m 45s	remaining: 5m 19s
# 311:	total: 8m 47s	remaining: 5m 17s
# 312:	total: 8m 49s	remaining: 5m 16s
# 313:	total: 8m 50s	remaining: 5m 14s
# 314:	total: 8m 51s	remaining: 5m 12s
# 315:	total: 8m 53s	remaining: 5m 10s
# 316:	total: 8m 54s	remaining: 5m 8s
# 317:	total: 8m 56s	remaining: 5m 7s
# 318:	total: 8m 58s	remaining: 5m 5s
# 319:	total: 9m	remaining: 5m 3s
# 320:	total: 9m 1s	remaining: 5m 2s
# 321:	total: 9m 3s	remaining: 5m
# 322:	total: 9m 4s	remaining: 4m 58s
# 323:	total: 9m 6s	remaining: 4m 56s
# 324:	total: 9m 7s	remaining: 4m 54s
# 325:	total: 9m 9s	remaining: 4m 53s
# 326:	total: 9m 10s	remaining: 4m 51s
# 327:	total: 9m 12s	remaining: 4m 49s
# 328:	total: 9m 13s	remaining: 4m 47s
# 329:	total: 9m 15s	remaining: 4m 45s
# 330:	total: 9m 16s	remaining: 4m 44s
# 331:	total: 9m 18s	remaining: 4m 42s
# 332:	total: 9m 19s	remaining: 4m 40s
# 333:	total: 9m 21s	remaining: 4m 39s
# 334:	total: 9m 22s	remaining: 4m 37s
# 335:	total: 9m 24s	remaining: 4m 35s
# 336:	total: 9m 26s	remaining: 4m 33s
# 337:	total: 9m 27s	remaining: 4m 32s
# 338:	total: 9m 29s	remaining: 4m 30s
# 339:	total: 9m 31s	remaining: 4m 28s
# 340:	total: 9m 32s	remaining: 4m 27s
# 341:	total: 9m 34s	remaining: 4m 25s
# 342:	total: 9m 35s	remaining: 4m 23s
# 343:	total: 9m 37s	remaining: 4m 21s
# 344:	total: 9m 38s	remaining: 4m 20s
# 345:	total: 9m 40s	remaining: 4m 18s
# 346:	total: 9m 41s	remaining: 4m 16s
# 347:	total: 9m 43s	remaining: 4m 14s
# 348:	total: 9m 44s	remaining: 4m 13s
# 349:	total: 9m 46s	remaining: 4m 11s
# 350:	total: 9m 48s	remaining: 4m 9s
# 351:	total: 9m 49s	remaining: 4m 7s
# 352:	total: 9m 51s	remaining: 4m 6s
# 353:	total: 9m 52s	remaining: 4m 4s
# 354:	total: 9m 54s	remaining: 4m 2s
# 355:	total: 9m 55s	remaining: 4m
# 356:	total: 9m 57s	remaining: 3m 59s
# 357:	total: 9m 59s	remaining: 3m 57s
# 358:	total: 10m 1s	remaining: 3m 56s
# 359:	total: 10m 2s	remaining: 3m 54s
# 360:	total: 10m 4s	remaining: 3m 52s
# 361:	total: 10m 5s	remaining: 3m 50s
# 362:	total: 10m 7s	remaining: 3m 49s
# 363:	total: 10m 8s	remaining: 3m 47s
# 364:	total: 10m 10s	remaining: 3m 45s
# 365:	total: 10m 12s	remaining: 3m 44s
# 366:	total: 10m 13s	remaining: 3m 42s
# 367:	total: 10m 14s	remaining: 3m 40s
# 368:	total: 10m 16s	remaining: 3m 38s
# 369:	total: 10m 18s	remaining: 3m 37s
# 370:	total: 10m 20s	remaining: 3m 35s
# 371:	total: 10m 21s	remaining: 3m 33s
# 372:	total: 10m 23s	remaining: 3m 32s
# 373:	total: 10m 25s	remaining: 3m 30s
# 374:	total: 10m 27s	remaining: 3m 29s
# 375:	total: 10m 28s	remaining: 3m 27s
# 376:	total: 10m 30s	remaining: 3m 25s
# 377:	total: 10m 32s	remaining: 3m 24s
# 378:	total: 10m 33s	remaining: 3m 22s
# 379:	total: 10m 35s	remaining: 3m 20s
# 380:	total: 10m 36s	remaining: 3m 18s
# 381:	total: 10m 38s	remaining: 3m 17s
# 382:	total: 10m 39s	remaining: 3m 15s
# 383:	total: 10m 41s	remaining: 3m 13s
# 384:	total: 10m 42s	remaining: 3m 11s
# 385:	total: 10m 44s	remaining: 3m 10s
# 386:	total: 10m 45s	remaining: 3m 8s
# 387:	total: 10m 47s	remaining: 3m 6s
# 388:	total: 10m 48s	remaining: 3m 5s
# 389:	total: 10m 50s	remaining: 3m 3s
# 390:	total: 10m 51s	remaining: 3m 1s
# 391:	total: 10m 52s	remaining: 2m 59s
# 392:	total: 10m 54s	remaining: 2m 58s
# 393:	total: 10m 55s	remaining: 2m 56s
# 394:	total: 10m 57s	remaining: 2m 54s
# 395:	total: 10m 59s	remaining: 2m 53s
# 396:	total: 11m 1s	remaining: 2m 51s
# 397:	total: 11m 2s	remaining: 2m 49s
# 398:	total: 11m 4s	remaining: 2m 48s
# 399:	total: 11m 5s	remaining: 2m 46s
# 400:	total: 11m 7s	remaining: 2m 44s
# 401:	total: 11m 8s	remaining: 2m 43s
# 402:	total: 11m 10s	remaining: 2m 41s
# 403:	total: 11m 11s	remaining: 2m 39s
# 404:	total: 11m 13s	remaining: 2m 37s
# 405:	total: 11m 14s	remaining: 2m 36s
# 406:	total: 11m 16s	remaining: 2m 34s
# 407:	total: 11m 17s	remaining: 2m 32s
# 408:	total: 11m 19s	remaining: 2m 31s
# 409:	total: 11m 20s	remaining: 2m 29s
# 410:	total: 11m 22s	remaining: 2m 27s
# 411:	total: 11m 24s	remaining: 2m 26s
# 412:	total: 11m 27s	remaining: 2m 24s
# 413:	total: 11m 29s	remaining: 2m 23s
# 414:	total: 11m 31s	remaining: 2m 21s
# 415:	total: 11m 33s	remaining: 2m 20s
# 416:	total: 11m 35s	remaining: 2m 18s
# 417:	total: 11m 36s	remaining: 2m 16s
# 418:	total: 11m 38s	remaining: 2m 14s
# 419:	total: 11m 39s	remaining: 2m 13s
# 420:	total: 11m 41s	remaining: 2m 11s
# 421:	total: 11m 42s	remaining: 2m 9s
# 422:	total: 11m 44s	remaining: 2m 8s
# 423:	total: 11m 46s	remaining: 2m 6s
# 424:	total: 11m 47s	remaining: 2m 4s
# 425:	total: 11m 49s	remaining: 2m 3s
# 426:	total: 11m 50s	remaining: 2m 1s
# 427:	total: 11m 52s	remaining: 1m 59s
# 428:	total: 11m 53s	remaining: 1m 58s
# 429:	total: 11m 55s	remaining: 1m 56s
# 430:	total: 11m 56s	remaining: 1m 54s
# 431:	total: 11m 58s	remaining: 1m 53s
# 432:	total: 12m 1s	remaining: 1m 51s
# 433:	total: 12m 2s	remaining: 1m 49s
# 434:	total: 12m 4s	remaining: 1m 48s
# 435:	total: 12m 5s	remaining: 1m 46s
# 436:	total: 12m 7s	remaining: 1m 44s
# 437:	total: 12m 8s	remaining: 1m 43s
# 438:	total: 12m 10s	remaining: 1m 41s
# 439:	total: 12m 11s	remaining: 1m 39s
# 440:	total: 12m 13s	remaining: 1m 38s
# 441:	total: 12m 14s	remaining: 1m 36s
# 442:	total: 12m 16s	remaining: 1m 34s
# 443:	total: 12m 18s	remaining: 1m 33s
# 444:	total: 12m 19s	remaining: 1m 31s
# 445:	total: 12m 21s	remaining: 1m 29s
# 446:	total: 12m 22s	remaining: 1m 28s
# 447:	total: 12m 24s	remaining: 1m 26s
# 448:	total: 12m 25s	remaining: 1m 24s
# 449:	total: 12m 27s	remaining: 1m 23s
# 450:	total: 12m 29s	remaining: 1m 21s
# 451:	total: 12m 30s	remaining: 1m 19s
# 452:	total: 12m 32s	remaining: 1m 18s
# 453:	total: 12m 33s	remaining: 1m 16s
# 454:	total: 12m 35s	remaining: 1m 14s
# 455:	total: 12m 36s	remaining: 1m 13s
# 456:	total: 12m 38s	remaining: 1m 11s
# 457:	total: 12m 39s	remaining: 1m 9s
# 458:	total: 12m 41s	remaining: 1m 8s
# 459:	total: 12m 42s	remaining: 1m 6s
# 460:	total: 12m 44s	remaining: 1m 4s
# 461:	total: 12m 45s	remaining: 1m 2s
# 462:	total: 12m 47s	remaining: 1m 1s
# 463:	total: 12m 48s	remaining: 59.7s
# 464:	total: 12m 50s	remaining: 58s
# 465:	total: 12m 51s	remaining: 56.3s
# 466:	total: 12m 53s	remaining: 54.6s
# 467:	total: 12m 54s	remaining: 53s
# 468:	total: 12m 56s	remaining: 51.3s
# 469:	total: 12m 57s	remaining: 49.7s
# 470:	total: 12m 59s	remaining: 48s
# 471:	total: 13m 1s	remaining: 46.4s
# 472:	total: 13m 2s	remaining: 44.7s
# 473:	total: 13m 4s	remaining: 43s
# 474:	total: 13m 5s	remaining: 41.4s
# 475:	total: 13m 7s	remaining: 39.7s
# 476:	total: 13m 8s	remaining: 38s
# 477:	total: 13m 10s	remaining: 36.4s
# 478:	total: 13m 12s	remaining: 34.7s
# 479:	total: 13m 13s	remaining: 33.1s
# 480:	total: 13m 15s	remaining: 31.4s
# 481:	total: 13m 17s	remaining: 29.8s
# 482:	total: 13m 19s	remaining: 28.1s
# 483:	total: 13m 20s	remaining: 26.5s
# 484:	total: 13m 22s	remaining: 24.8s
# 485:	total: 13m 23s	remaining: 23.1s
# 486:	total: 13m 25s	remaining: 21.5s
# 487:	total: 13m 27s	remaining: 19.9s
# 488:	total: 13m 29s	remaining: 18.2s
# 489:	total: 13m 30s	remaining: 16.5s
# 490:	total: 13m 32s	remaining: 14.9s
# 491:	total: 13m 34s	remaining: 13.2s
# 492:	total: 13m 35s	remaining: 11.6s
# 493:	total: 13m 37s	remaining: 9.93s
# 494:	total: 13m 39s	remaining: 8.28s
# 495:	total: 13m 40s	remaining: 6.62s
# 496:	total: 13m 42s	remaining: 4.96s
# 497:	total: 13m 44s	remaining: 3.31s
# 498:	total: 13m 45s	remaining: 1.65s
# 499:	total: 13m 47s	remaining: 0us
# Accuracy score using CountVectorizer and CatBoost: 0.8897922312556459

# %%
y_pred_class_cbc = ovr.predict_proba(x_test_vectorized)

# %% [markdown]
# ### Ensemble

# %%
from sklearn import metrics

y_pred_all = (y_pred_class_svc + y_pred_class_cbc) / 2
print("Auroc SVC: ", metrics.roc_auc_score(y_test, y_pred_class_svc, average='micro'))
print("Auroc CBC: ", metrics.roc_auc_score(y_test, y_pred_class_cbc, average='micro'))
print("Auroc Ensemble: ", metrics.roc_auc_score(y_test, y_pred_all, average='micro'))
print()
print("Avg Precision SVC: ", metrics.average_precision_score(y_test, y_pred_class_svc))
print("Avg Precision CBC: ", metrics.average_precision_score(y_test, y_pred_class_cbc))
print("Avg Precision Ensemble: ", metrics.average_precision_score(y_test, y_pred_all))
# Out:
# Auroc SVC:  0.9845611049659462
# Auroc CBC:  0.9933280669998557
# Auroc Ensemble:  0.9940516292737024
#
# Avg Precision SVC:  0.9800701950287888
# Avg Precision CBC:  0.9923272894179451
# Avg Precision Ensemble:  0.9915446877902869

# %%
y_pred_all = (y_pred_class_svc + y_pred_NN) / 2
print("Auroc SVC: ", metrics.roc_auc_score(y_test, y_pred_class_svc, average='micro'))
print("Auroc NN: ", metrics.roc_auc_score(y_test, y_pred_NN, average='micro'))
print("Auroc Ensemble: ", metrics.roc_auc_score(y_test, y_pred_all, average='micro'))
print()
print("Avg Precision SVC: ", metrics.average_precision_score(y_test, y_pred_class_svc))
print("Avg Precision NN: ", metrics.average_precision_score(y_test, y_pred_NN))
print("Avg Precision Ensemble: ", metrics.average_precision_score(y_test, y_pred_all))
# Out:
# Auroc SVC:  0.9845611049659462
# Auroc NN:  0.9917277015606184
# Auroc Ensemble:  0.9942474410411195
#
# Avg Precision SVC:  0.9800701950287888
# Avg Precision NN:  0.9881654680578972
# Avg Precision Ensemble:  0.9923909978361127

# %%
y_pred_all = (y_pred_NN + y_pred_class_cbc) / 2
print("Auroc NN: ", metrics.roc_auc_score(y_test, y_pred_NN, average='micro'))
print("Auroc CBC: ", metrics.roc_auc_score(y_test, y_pred_class_cbc, average='micro'))
print("Auroc Ensemble: ", metrics.roc_auc_score(y_test, y_pred_all, average='micro'))
print()
print("Avg Precision NN: ", metrics.average_precision_score(y_test, y_pred_NN))
print("Avg Precision CBC: ", metrics.average_precision_score(y_test, y_pred_class_cbc))
print("Avg Precision Ensemble: ", metrics.average_precision_score(y_test, y_pred_all))
# Out:
# Auroc NN:  0.9917277015606184
# Auroc CBC:  0.9933280669998557
# Auroc Ensemble:  0.9948745235912533
#
# Avg Precision NN:  0.9881654680578972
# Avg Precision CBC:  0.9923272894179451
# Avg Precision Ensemble:  0.9935876305800739

# %%
y_pred_all = (y_pred_NN + y_pred_class_svc + y_pred_class_cbc) / 3
print("Auroc SVC: ", metrics.roc_auc_score(y_test, y_pred_class_svc, average='micro'))
print("Auroc NN: ", metrics.roc_auc_score(y_test, y_pred_NN, average='micro'))
print("Auroc CBC: ", metrics.roc_auc_score(y_test, y_pred_class_cbc, average='micro'))
print("Auroc Ensemble: ", metrics.roc_auc_score(y_test, y_pred_all, average='micro'))
print()
print("Avg Precision SVC: ", metrics.average_precision_score(y_test, y_pred_class_svc))
print("Avg Precision NN: ", metrics.average_precision_score(y_test, y_pred_NN))
print("Avg Precision CBC: ", metrics.average_precision_score(y_test, y_pred_class_cbc))
print("Avg Precision Ensemble: ", metrics.average_precision_score(y_test, y_pred_all))
# Out:
# Auroc SVC:  0.9845611049659462
# Auroc NN:  0.9917277015606184
# Auroc CBC:  0.9933280669998557
# Auroc Ensemble:  0.9956017225730892
#
# Avg Precision SVC:  0.9800701950287888
# Avg Precision NN:  0.9881654680578972
# Avg Precision CBC:  0.9923272894179451
# Avg Precision Ensemble:  0.9941236079634563

# %%
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Preparing for submission

# %%
train = pd.read_csv("TIL_NLP_train_dataset.csv")
test = pd.read_csv("TIL_NLP_test_dataset.csv")
print(train.shape)
print(test.shape)

train_input = train["word_representation"]
train_labels = train[train.columns[2:]]
test_input = test["word_representation"]
test_id = test["id"]

print(train_input.head(1))
print(train_labels.head(1))
print(test_input.head(1))
# Out:
# (7380, 7)
# (2460, 2)
# 0    w7718 w173355 w138132 w232277 w90685 w314686 w...
# Name: word_representation, dtype: object
#    outwear  top  trousers  women dresses  women skirts
# 0        1    0         1              0             0
# 0    w373517 w383437 w374393 w87179 w289496 w327385...
# Name: word_representation, dtype: object

# %%
max_features = 100000
maxlen = 100
embed_size = 100

print('preprocessing start')

# finally, vectorize the text samples into a 2D integer tensor
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(train_input) + list(test_input))

X_train1 = tokenizer.texts_to_sequences(train_input)
X_test1 = tokenizer.texts_to_sequences(test_input)
x_train_seq = sequence.pad_sequences(X_train1, maxlen=maxlen)
x_test_seq = sequence.pad_sequences(X_test1, maxlen=maxlen)


word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

### Read pkl file provided
import gc
import pickle 
with open("word_embeddings.pkl",'rb') as g:
    embeddings_index = pickle.load(g)

all_embs = np.stack(embeddings_index.values())
emb_mean, emb_std = all_embs.mean(), all_embs.std()

word_index = tokenizer.word_index
nb_words = len(word_index)+1
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector
        
print('preprocessing done')
# Out:
# preprocessing start
# Found 4620 unique tokens.
# C:\Users\lim_k\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3249: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if (await self.run_code(code, result,  async_=asy)):
# preprocessing done

# %%
filter_nr = 64
filter_size = 6
max_pool_size = 4
max_pool_strides = 2
train_embed = False
conv_kern_reg = regularizers.l2(0.00001)
conv_bias_reg = regularizers.l2(0.00001)

model = Sequential()
model.add(Embedding(nb_words, embed_size, weights=[embedding_matrix], trainable=train_embed))
model.add(Conv1D(filters = 256, kernel_size=6, padding='same', activation='relu',
                kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(Dropout(0.5))
model.add(Conv1D(filters = 128, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(BatchNormalization())
model.add(Conv1D(filters = 64, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(Conv1D(filters = 32, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(Dropout(0.2))
model.add(Conv1D(filters = 16, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(BatchNormalization())
model.add(Conv1D(filters = 8, kernel_size=filter_size, padding='same', activation='relu', 
            kernel_regularizer=conv_kern_reg, bias_regularizer=conv_bias_reg))
model.add(MaxPooling1D(pool_size=2))
model.add(Bidirectional(LSTM(150)))
model.add(Dense(5, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 100)         462100
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, None, 256)         153856
# _________________________________________________________________
# dropout_6 (Dropout)          (None, None, 256)         0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, None, 128)         196736
# _________________________________________________________________
# batch_normalization_6 (Batch (None, None, 128)         512
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, None, 64)          49216
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, None, 32)          12320
# _________________________________________________________________
# dropout_7 (Dropout)          (None, None, 32)          0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, None, 16)          3088
# _________________________________________________________________
# batch_normalization_7 (Batch (None, None, 16)          64
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, None, 8)           776
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, None, 8)           0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 300)               190800
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 1505
# =================================================================
# Total params: 1,070,973
# Trainable params: 608,585
# Non-trainable params: 462,388
# _________________________________________________________________
# None

# %%
model.compile(loss='binary_crossentropy', 
            optimizer='adam',
            metrics=['accuracy'])
            
batch_size = 128
epochs = 50


history = model.fit(x_train_seq[:-100], train_labels[:-100], batch_size=batch_size, epochs=epochs,
                    validation_data=(x_train_seq[-100:], train_labels[-100:]),verbose=1, shuffle = True,
                   callbacks=[EarlyStopping(monitor='val_loss', patience=5, min_delta=0.00005)])

yhat = model.predict(x_test, verbose=0)
# Out:
# Train on 7280 samples, validate on 100 samples
# Epoch 1/50
#  768/7280 [==>...........................] - ETA: 1:00 - loss: 0.6287 - accuracy: 0.6075WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-61a9447cf565> in <module>
#       9 history = model.fit(x_train_seq[:-100], train_labels[:-100], batch_size=batch_size, epochs=epochs,
#      10                     validation_data=(x_train_seq[-100:], train_labels[-100:]),verbose=1, shuffle = True,
# ---> 11                    callbacks=[EarlyStopping(monitor='val_loss', patience=5, min_delta=0.00005)])
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# list all data in history
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
cvect = TfidfVectorizer(analyzer='word', ngram_range=(1,6),max_df=1.0,
                        max_features=None, min_df=1)
cvect.fit(train_input)
x_train_vectorized = cvect.transform(train_input)
x_test_vectorized = cvect.transform(test_input)

print(x_train_vectorized.shape)
print(x_test_vectorized.shape)
print(train_labels.shape)

# %%
### SVC
clf1 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 
clf2 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 
clf3 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 
clf4 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 
clf5 = CalibratedClassifierCV(LinearSVC(C=0.32, penalty="l2")) 

"outwear", "top", "trousers", "women dresses", "women skirts"
clf1.fit(x_train_vectorized, y_train["outwear"])
clf2.fit(x_train_vectorized, y_train["top"])
clf3.fit(x_train_vectorized, y_train["trousers"])
clf4.fit(x_train_vectorized, y_train["women dresses"])
clf5.fit(x_train_vectorized, y_train["women skirts"])


y_pred1 = clf1.predict_proba(x_test_vectorized)[:, 1]
y_pred2 = clf2.predict_proba(x_test_vectorized)[:, 1]
y_pred3 = clf3.predict_proba(x_test_vectorized)[:, 1]
y_pred4 = clf4.predict_proba(x_test_vectorized)[:, 1]
y_pred5 = clf5.predict_proba(x_test_vectorized)[:, 1]

y_pred_class_svc = np.stack((y_pred1,y_pred2,y_pred3, y_pred4, y_pred5), axis = 1)

# %%
### CatBoost
from catboost import CatBoostClassifier
from sklearn.multiclass import OneVsRestClassifier

ovr = OneVsRestClassifier(estimator=CatBoostClassifier(loss_function='MultiClass',eval_metric='AUC'
                                                       , verbose=1,learning_rate = 0.1,
                                                      iterations = 1000, rsm = 0.1))
ovr.fit(x_train_vectorized,y_train)

y_pred_class_cbc = ovr.predict_proba(x_test_vectorized)

# %%
y_pred_all = (y_pred_NN + y_pred_class_svc + y_pred_class_cbc) / 3
preds_labels = [[1 if x > 0.5 else 0 for idx,x in enumerate(i) ] for i in y_pred_all]

# %%
labels = pd.DataFrame(preds_labels, columns = ["outwear", "top", "trousers", "women dresses", "women skirts"])
output = pd.concat([test_id , labels], axis = 1)
output.head(3)
output.to_csv('submission5.csv',index = False)
